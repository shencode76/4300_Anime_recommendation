# %% [markdown]
# # DS4300 Project -- Anime Recommendation Engine
# ## Professor John Rachlin
# ## Group Member: Wenting Yue, Xiaofei Xie, Yuhan Wang, Yuxi Shen

# %%
import pandas as pd
# Out:
# /Users/shenyuxi/opt/anaconda3/lib/python3.8/site-packages/pandas/core/computation/expressions.py:20: UserWarning: Pandas requires version '2.7.3' or newer of 'numexpr' (version '2.7.1' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED

# %%
df = pd.read_csv("AnimeList.csv")
df_anime = df.drop(["title_english", "title_japanese", "title_synonyms", "image_url", "status", "aired", "background", "related", "licensor", "opening_theme", "ending_theme"], axis=1)
df_anime.shape
# Out:
# (14478, 20)

# %%
df_anime.dropna(inplace=True)
print(df_anime.shape)
df_anime.head(5)
# Out:
# (2672, 20)
#    anime_id                title type    source  episodes  airing  \
# 0     11013        Inu x Boku SS   TV     Manga        12   False
# 1      2104     Seto no Hanayome   TV     Manga        26   False
# 2      5262   Shugo Chara!! Doki   TV     Manga        51   False
# 3       721        Princess Tutu   TV  Original        38   False
# 4     12365  Bakuman. 3rd Season   TV     Manga        25   False
#
#                    aired_string         duration                     rating  \
# 0  Jan 13, 2012 to Mar 30, 2012  24 min. per ep.  PG-13 - Teens 13 or older
# 1    Apr 2, 2007 to Oct 1, 2007  24 min. per ep.  PG-13 - Teens 13 or older
# 2   Oct 4, 2008 to Sep 25, 2009  24 min. per ep.              PG - Children
# 3  Aug 16, 2002 to May 23, 2003  16 min. per ep.  PG-13 - Teens 13 or older
# 4   Oct 6, 2012 to Mar 30, 2013  24 min. per ep.  PG-13 - Teens 13 or older
#
#    score  scored_by    rank  popularity  members  favorites    premiered  \
# ...

# %%
df_anime.dtypes
# Out:
# anime_id          int64
# title            object
# type             object
# source           object
# episodes          int64
# airing             bool
# aired_string     object
# duration         object
# rating           object
# score           float64
# scored_by         int64
# rank            float64
# popularity        int64
# members           int64
# favorites         int64
# premiered        object
# broadcast        object
# producer         object
# studio           object
# genre            object
# dtype: object

# %% [markdown]
# df_anime.to_json('anime.json', orient = 'index')

# %% [markdown]
# df_anime.to_csv('anime.csv')

# %%
df_anime.loc[20]["genre"]
# Out:
# 'Comedy, Drama, Romance, Shounen'

# %%
df["genre1"] = str(df["genre"]).split(",")[0]
df
# Out:
#        anime_id                                  title  \
# 0         11013                          Inu x Boku SS
# 1          2104                       Seto no Hanayome
# 2          5262                     Shugo Chara!! Doki
# 3           721                          Princess Tutu
# 4         12365                    Bakuman. 3rd Season
# ...         ...                                    ...
# 14473     26089             Gutchonpa Omoshiro Hanashi
# 14474     21525                   Geba Geba Shou Time!
# 14475     37897            Godzilla: Hoshi wo Kuu Mono
# 14476     34193  Nippon Mukashibanashi: Sannen Netarou
# 14477     37908             Senjou no Valkyria Special
#
#                    title_english                  title_japanese  \
# 0      Inu X Boku Secret Service                          妖狐×僕SS
# 1          My Bride is a Mermaid                           瀬戸の花嫁
# 2             Shugo Chara!! Doki                     しゅごキャラ！！どきっ
# ...

# %%
df["genre2"] = str(df["genre"]).split(",")[1]
df
# Out:
#        anime_id                                  title  \
# 0         11013                          Inu x Boku SS
# 1          2104                       Seto no Hanayome
# 2          5262                     Shugo Chara!! Doki
# 3           721                          Princess Tutu
# 4         12365                    Bakuman. 3rd Season
# ...         ...                                    ...
# 14473     26089             Gutchonpa Omoshiro Hanashi
# 14474     21525                   Geba Geba Shou Time!
# 14475     37897            Godzilla: Hoshi wo Kuu Mono
# 14476     34193  Nippon Mukashibanashi: Sannen Netarou
# 14477     37908             Senjou no Valkyria Special
#
#                    title_english                  title_japanese  \
# 0      Inu X Boku Secret Service                          妖狐×僕SS
# 1          My Bride is a Mermaid                           瀬戸の花嫁
# 2             Shugo Chara!! Doki                     しゅごキャラ！！どきっ
# ...

# %%
df["genre3"] = str(df["genre"]).split(",")[2]
df
# Out:
#        anime_id                                  title  \
# 0         11013                          Inu x Boku SS
# 1          2104                       Seto no Hanayome
# 2          5262                     Shugo Chara!! Doki
# 3           721                          Princess Tutu
# 4         12365                    Bakuman. 3rd Season
# ...         ...                                    ...
# 14473     26089             Gutchonpa Omoshiro Hanashi
# 14474     21525                   Geba Geba Shou Time!
# 14475     37897            Godzilla: Hoshi wo Kuu Mono
# 14476     34193  Nippon Mukashibanashi: Sannen Netarou
# 14477     37908             Senjou no Valkyria Special
#
#                    title_english                  title_japanese  \
# 0      Inu X Boku Secret Service                          妖狐×僕SS
# 1          My Bride is a Mermaid                           瀬戸の花嫁
# 2             Shugo Chara!! Doki                     しゅごキャラ！！どきっ
# ...

# %%
# df.to_csv("anime_updated.csv")
