# %%
import pandas as pd
# Out:
# /Users/shenyuxi/opt/anaconda3/lib/python3.8/site-packages/pandas/core/computation/expressions.py:20: UserWarning: Pandas requires version '2.7.3' or newer of 'numexpr' (version '2.7.1' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED

# %%
df = pd.read_csv("AnimeList.csv")
df = df.drop(["title_english", "title_japanese", "title_synonyms", "image_url", "status", "aired", "background", "related", "licensor", "opening_theme", "ending_theme"], axis=1)
df.dropna(inplace=True)
df['genre1'] = df['genre'].str.split(',').str[0]
df['genre2'] = df['genre'].str.split(',').str[1]
df['genre3'] = df['genre'].str.split(',').str[2]
df.drop('genre', axis=1, inplace=True)

# %%
import random
def length_of_eposide(length):
    if 'min. per ep.' in length:
        duration = length.replace('min. per ep.', '')
    elif 'min' in length:
        duration = length.replace('min.', '')
    elif 'Unknown' in length:
        duration = '0'
    elif 'sec. per ep.' in length:
        duration = length.replace('sec. per ep.', '')
        duration = int(duration) / 60
    return int(duration)

df['duration'] = df['duration'].apply(length_of_eposide)
df
# random.seed(100)
df = df.sample(n=100, random_state = 100)

# %%
df.head()
# Out:
#        anime_id                                 title type    source  \
# 5006      12119                      Natsu-iro Kiseki   TV  Original
# 1191        527                               Pokemon   TV      Game
# 7211       1175                    Metal Fighter Miku   TV  Original
# 7236       1915  Mahou Shoujo Lyrical Nanoha StrikerS   TV  Original
# 13540     12883                             Tsuritama   TV  Original
#
#        episodes  airing                  aired_string  duration  \
# 5006         12   False   Apr 6, 2012 to Jun 29, 2012        24
# 1191        276   False   Apr 1, 1997 to Nov 14, 2002        24
# 7211         13   False   Jul 8, 1994 to Sep 30, 1994        25
# 7236         26   False   Apr 2, 2007 to Sep 24, 2007        25
# 13540        12   False  Apr 13, 2012 to Jun 29, 2012        23
#
#                           rating  score  ...  popularity  members  favorites  \
# 5006   PG-13 - Teens 13 or older   7.04  ...        2043    31880         72
# 1191               PG - Children   7.42  ...         214   298374       3737
# 7211   PG-13 - Teens 13 or older   6.10  ...        6905     1953          5
# 7236   PG-13 - Teens 13 or older   7.72  ...        1766    40381        572
# 13540  PG-13 - Teens 13 or older   7.79  ...         788   109377       1986
#
#          premiered                 broadcast  \
# 5006   Spring 2012                   Unknown
# 1191   Spring 1997  Thursdays at 19:00 (JST)
# 7211   Summer 1994                   Unknown
# 7236   Spring 2007                   Unknown
# 13540  Spring 2012    Fridays at 01:15 (JST)
#
#                                                 producer        studio  \
# 5006   Aniplex, Lantis, Mainichi Broadcasting System,...       Sunrise
# 1191               TV Tokyo, TV Tokyo Music, Studio Jack           OLM
# 7211                   Victor Entertainment, Studio Jack     J.C.Staff
# 7236   Geneon Universal Entertainment, A-Line, King R...    Seven Arcs
# 13540  Aniplex, Dentsu, Fuji TV, tsuritama partners, ...  A-1 Pictures
#
#        genre1          genre2          genre3
# 5006   School   Slice of Life    Supernatural
# 1191   Action       Adventure          Comedy
# 7211   Sci-Fi          Comedy          Sports
# 7236   Action           Magic          Comedy
# 13540  Comedy          Sci-Fi   Slice of Life
#
# [5 rows x 22 columns]

# %%
import numpy as np

def combined_distance(anime_a, anime_b, numeric_features, categorical_features, vdm_data):
    # Euclidean distance for numeric features
    euclidean = 0
    for feature in numeric_features:
        euclidean += (anime_a[feature] - anime_b[feature]) ** 2
    euclidean = np.sqrt(euclidean)

    # VDM distance for categorical features
    vdm_distance = 0
    for feature in categorical_features:
        attribute_data = vdm_data[feature]
        category1 = anime_a[feature]
        category2 = anime_b[feature]

        total_difference = 0
        for category in attribute_data:
            probability1 = attribute_data[category].get(category1, 0)
            probability2 = attribute_data[category].get(category2, 0)
            total_difference += (probability1 - probability2) ** 2

        vdm_distance += (total_difference ** 0.5) ** 2

    vdm_distance = np.sqrt(vdm_distance)

    # Combine Euclidean and VDM distances
    combined = (euclidean + vdm_distance) / 2

    return combined

# %%
list_of_categorical_features = ['source', 'type', 'rating','premiered','studio','genre1','genre2','genre3']

# %%
list_of_numeric_features = ['episodes','score','rank','popularity','scored_by','members','favorites','duration']

# %%
vdm_data = {}

for feature in list_of_categorical_features:
    feature_data = df[feature].value_counts(normalize=True).to_dict()
    vdm_data[feature] = {}
    
    for category1 in feature_data.keys():
        vdm_data[feature][category1] = {}
        for category2 in feature_data.keys():
            if category1 == category2:
                vdm_data[feature][category1][category2] = 0
            else:
                vdm_data[feature][category1][category2] = abs(feature_data[category1] - feature_data[category2])

# Create a similarity matrix
similarity_matrix = np.zeros((len(df), len(df)))
count = 0
for i in range(len(df)):
    for j in range(len(df)):
        if i != j:
            similarity_matrix[i][j] = combined_distance(df.iloc[i], df.iloc[j], list_of_numeric_features,
                                                        list_of_categorical_features, vdm_data)

# %%
np.median(similarity_matrix)
# Out:
# 31231.72384896173

# %%
# pip install neo4j

# %%
# from neo4j import GraphDatabase
# from py2neo import Graph

# %%
# import pandas as pd
# import numpy as np
# from py2neo import Graph, Node, Relationship
# graph = Graph("bolt://localhost:7687", auth=("neo4j", "Ywt200151753."))
# graph.delete_all()

# # create nodes for the songs in the sample
# for index, Anime in df.iterrows():
#     node = Node('Anime', id=Anime['anime_id'], name=Anime['title'],
#                 source=Anime['source'], type=Anime['type'],
#                 rating=Anime['rating'], premiered=Anime['premiered'], studio=Anime['studio'],
#                 genre1=Anime['genre1'], genre2=Anime['genre2'],genre3=Anime['genre3'], episodes=Anime['episodes'],
#                 score=Anime['score'], rank=Anime['rank'], popularity=Anime['popularity'],
#                 scored_by=Anime['scored_by'], members=Anime['members'], favorites=Anime['favorites'],
#                 duration=Anime['duration'])
#     graph.create(node)
    
# anime_nodes = list(graph.nodes.match("Anime"))

# %%
# # iterate over the similarity matrix and create relationships between the nodes
# for i in range(len(df)):
#     for j in range(0, i):
#         anime1 = anime_nodes[i]
#         anime2 = anime_nodes[j]
#         distance = float(similarity_matrix[i][j])

#         # create relationship between the songs that meet threshold
#         if distance < 3000:
#         # create a similarity relationship between the songs
#             similarity_rel = Relationship(anime1, "SIMILAR_TO", anime2, distance=distance)
#             print(similarity_rel)
#         # create the relationship in the database
#             graph.create(similarity_rel)

# %%
# from flask import Flask, render_template, request
# import json
# from py2neo import Graph

# app = Flask(__name__)

# # create a connection to the Neo4j database
# graph = Graph("bolt://localhost:7687", auth=("neo4j", "Ywt200151753."))

# @app.route('/')
# def index():
#     return render_template('index.html')

# @app.route('/recommend', methods=['POST'])
# def recommend():
#     favorites = request.form['favorites']
#     favorites_list = favorites.split(',')

#     cypher_query = """
#         MATCH (a1:Anime)-[r:SIMILAR_TO]->(a2:Anime)
#         WHERE a1.name IN {favorites_list}
#         AND NOT a2.name IN {favorites_list}
#         WITH a1, a2, r, MIN(r.distance) AS min_distance
#         ORDER BY min_distance ASC
#         Limit 5
#         RETURN a1, r, a2
#     """

#     results = graph.run(cypher_query, parameters={'favorites_list': favorites_list})

#     recommendations = []
#     for record in results:
#         recommendations.append({
#             'title': record['a2']['name'],
#             'studio': record['a2']['studio'],
#             'distance': record['min_distance']
#         })

#     return json.dumps(recommendations)

# if __name__ == '__main__':
#     app.run(debug=True)

# %%
import tkinter as tk
from tkinter import ttk
import numpy as np
import pandas as pd
from neo4j import GraphDatabase
from neo4j.exceptions import ServiceUnavailable
from py2neo import Relationship


def get_recommendations():
    # Get the user input from the entry widget
    user_input = user_input_entry.get()

    if not user_input:
        return

    # Pass the user input to the function as a parameter
    process_recommendations(user_input)
    print(f"Processed user input: {user_input}") 


def process_recommendations(animes):
    try:
        driver = GraphDatabase.driver("bolt://localhost:7687", auth=("neo4j", "Shenyuxi76!"))
        graph = driver.session()

        # Create a similarity matrix
#         similarity_matrix = np.zeros((len(df), len(df)))
#         count = 0
#         for i in range(len(df)):
#             for j in range(len(df)):
#                 if i != j:
#                     similarity_matrix[i][j] = combined_distance(df.iloc[i], df.iloc[j], list_of_numeric_features,
#                                                                 list_of_categorical_features, vdm_data)

#         # Create nodes for the songs in the sample
#         for index, Anime in df.iterrows():
#             node = Node('Anime', id=Anime['anime_id'], name=Anime['title'],
#                         source=Anime['source'], type=Anime['type'],
#                         rating=Anime['rating'], premiered=Anime['premiered'], studio=Anime['studio'],
#                         genre1=Anime['genre1'], genre2=Anime['genre2'], genre3=Anime['genre3'], episodes=Anime['episodes'],
#                         score=Anime['score'], rank=Anime['rank'], popularity=Anime['popularity'],
#                         scored_by=Anime['scored_by'], members=Anime['members'], favorites=Anime['favorites'],
#                         duration=Anime['duration'])
#             graph.create(node)

        for index, Anime in df.iterrows():
                    query = """
                    CREATE (a:Anime {
                        id: $anime_id, name: $title, source: $source, type: $type,
                        rating: $rating, premiered: $premiered, studio: $studio,
                        genre1: $genre1, genre2: $genre2, genre3: $genre3, episodes: $episodes,
                        score: $score, rank: $rank, popularity: $popularity,
                        scored_by: $scored_by, members: $members, favorites: $favorites,
                        duration: $duration
                    })
                    """
                    graph.run(query, {
                        'anime_id': Anime['anime_id'],
                        'title': Anime['title'],
                        'source': Anime['source'],
                        'type': Anime['type'],
                        'rating': Anime['rating'],
                        'premiered': Anime['premiered'],
                        'studio': Anime['studio'],
                        'genre1': Anime['genre1'],
                        'genre2': Anime['genre2'],
                        'genre3': Anime['genre3'],
                        'episodes': Anime['episodes'],
                        'score': Anime['score'],
                        'rank': Anime['rank'],
                        'popularity': Anime['popularity'],
                        'scored_by': Anime['scored_by'],
                        'members': Anime['members'],
                        'favorites': Anime['favorites'],
                        'duration': Anime['duration']
                    })

        #anime_nodes = list(graph.nodes.match("Anime"))
        query = "MATCH (a:Anime) RETURN a"
        anime_nodes = [record["a"] for record in graph.run(query)]

        # Iterate over the similarity matrix and create relationships between the nodes
        for i in range(len(df)):
            for j in range(0, i):
                anime1 = anime_nodes[i]
                anime2 = anime_nodes[j]
                distance = float(similarity_matrix[i][j])
                print(distance)

                # Create a relationship between the songs that meet the threshold
                if distance < 10000:
#                     # Create a similarity relationship between the songs
#                     similarity_rel = Relationship(anime1, "SIMILAR_TO", anime2, distance=distance)

#                     # Create the relationship in the database
#                     graph.create(similarity_rel)
                        query = """
                        MATCH (a1:Anime {name: $anime1_name}), (a2:Anime {name: $anime2_name})
                        MERGE (a1)-[:SIMILAR_TO {distance: $distance}]->(a2)
                            """
                        graph.run(query, {
                            'anime1_name': anime1['name'],
                            'anime2_name': anime2['name'],
                            'distance': distance
                        })

        # Insert the code for the Cypher query here (cypher_query variable)
        # Define the input anime names
        list_of_anime = animes.split(',')
        input_anime_names = list_of_anime

        # Define the parameterized Cypher query
        cypher_query = """
        MATCH (a1:Anime)-[r:SIMILAR_TO]->(a2:Anime)
        WHERE a1.name IN $input_anime_names
        AND NOT a2.name IN $input_anime_names
        WITH a1, a2, r, MIN(r.distance) AS min_distance
        ORDER BY min_distance ASC
        Limit 5
        RETURN a1, r, a2
        """

        # Run the parameterized query with the input anime names as parameters
        print(f"Running query with input_anime_names: {input_anime_names}")
        results = graph.run(cypher_query, input_anime_names=input_anime_names)

        #results = graph.run(cypher_query)

        # Clear the existing recommendations
        recommendation_text.delete(1.0, tk.END)

        # Insert the recommendations into the text widget
        print(results)
        for record in results:
#             recommendation = f"Anime: {record['a2']['name']}, Studio: {record['a2']['studio']}"
#             print(recommendation)
            recommendation_text.insert(tk.END, f"Recommendations based on your preferences: \n Anime: {record['a2']['name']}, produced by Studio: {record['a2']['studio']}\n")

        graph.close()
    except ServiceUnavailable as e:
        print(f"Neo4j service unavailable: {e}")

# %%
# Create the main window
root = tk.Tk()
root.title("Anime Recommendation System")

# Create and pack the widgets
frame = ttk.Frame(root, padding="10")
frame.grid(row=0, column=0, sticky=(tk.W, tk.E, tk.N, tk.S))

# Add a label for the input entry
user_input_label = ttk.Label(frame, text="Enter comma-separated anime names:")
user_input_label.grid(row=0, column=0, sticky=tk.W, pady=(0, 5))

# Add an entry widget for user input
user_input_entry = ttk.Entry(frame, width=80)
user_input_entry.grid(row=1, column=0, pady=(0, 10))

# Change the command of the button to get_recommendations (without parentheses)
get_recommendations_button = ttk.Button(frame, text="Get Recommendations", command=get_recommendations)
get_recommendations_button.grid(row=2, column=0, pady=(0, 10))

recommendation_text = tk.Text(frame, wrap=tk.WORD, width=80, height=20)
recommendation_text.grid(row=3, column=0)

scrollbar = ttk.Scrollbar(frame, orient=tk.VERTICAL, command=recommendation_text.yview)
scrollbar.grid(row=3, column=1, sticky=(tk.N, tk.S))
recommendation_text["yscrollcommand"] = scrollbar.set

root.mainloop()
# Out:
# 155374.82875176592
# 16212.435219542656
# 171082.55601752954
# 6145.808760086817
# 149536.82631881192
# 21893.827657387537
# 41717.03487409535
# 114431.70142633097
# 57773.70731134128
# 36247.57195242217
# 18237.76108271334
# 172146.2397121546
# 3983.0456334881364
# 23784.155456959197
# 59133.47207413603
# 31748.17721452466
# 123680.10721441335
# 47478.974934790764
# 25912.771522946096
# 12660.251290727527
# 48816.13262761211
# 14237.96457414694
# 169223.87101750608
# 2347.9635523199586
# 20018.7911516462
# 55825.15734314923
# 5441.14460732747
# 45587.24558835206
# 19740.589227461118
# 135767.23707373865
# 35808.8347338045
# 14253.422094648435
# 22041.98604438777
# 37335.71810126047
# 12635.588281893384
# 33859.716071164476
# 15695.571086170288
# 170643.4838994242
# 2721.9944790387553
# 21247.078435722604
# 57279.05304395311
# 6237.321671672813
# 47040.836133388344
# 3672.7855045413844
# 35314.6988585566
# 16986.23353075767
# 171746.6930051128
# 1434.5173055179148
# 22598.48436149752
# 58466.82025984987
# 3733.9398035510135
# 48188.262994879035
# 3651.4611497355177
# 36527.769315057376
# 2598.867912736821
# 6875.719928003627
# 162038.31522920288
# 9647.953117766026
# 12521.725743202236
# 48529.311907908996
# 12276.13024285369
# 38384.36398551121
# 7819.029770443989
# 26540.94663900673
# 8878.578616235638
# 10392.722275550654
# 15194.258378385459
# 170254.21089750557
# 1435.8931793461888
# 20904.375556301027
# 56847.51205100683
# 5303.604656836052
# 46612.7242313867
# 1804.557989190351
# 34869.924445879
# 1953.6184598516465
# 2352.0012883469954
# 8509.877782955127
# 12638.579242411199
# 167828.56858326308
# 4918.114098992852
# 18315.05352569862
# 54247.37543615387
# 8422.042624966356
# 44200.53779161237
# 3935.3200007090795
# 32307.695293841083
# 3411.5671461990114
# 5433.129881143747
# 5848.686159868942
# 3530.2453841644715
# 125110.29658495626
# 30333.836192142906
# 140790.02165059836
# 119261.50196201542
# 84386.75455867851
# 141869.8149642445
# 93393.08912894322
# 138932.92125218842
# 105543.16867880517
# 140356.93473457012
# 141459.04379649382
# 131759.3254696301
# 139963.7408782701
# 137553.92851647883
# 3352.5689643911983
# 157106.1971846862
# 14453.122289076451
# 7640.954047086435
# 43864.95902928754
# 16719.533877682963
# 33479.540788143575
# 12664.710958458088
# 21859.646884780814
# 13671.101158505197
# 15148.677511727341
# 5095.815547457157
# 13407.820603658405
# 10807.349790970755
# 126820.31390678117
# 24017.792442208414
# 133702.59866968807
# 39883.918590033674
# 19595.52130357264
# 19355.423168365665
# 41380.06334750165
# 14758.875666616503
# 37884.96590417268
# 7865.085201753358
# 39410.958782359754
# 40595.851972854274
# 30767.96883262831
# 38910.121276481914
# 36246.050633384664
# 103692.66334711053
# 26673.58760661909
# 142380.24138443486
# 13516.22265324081
# 158021.30322697648
# 136515.1122812096
# 101711.69221542553
# 159082.77152325242
# 110650.1498310762
# 156174.06608103245
# 122838.82277503877
# 157588.1411649816
# 158686.0983158895
# 149010.98955502975
# 157201.78754975402
# 154803.89480023438
# 17329.42763229569
# 144059.43650417545
# 121015.76143903637
# 11327.91182519278
# 144939.15710494778
# 27386.28649841741
# 7187.263858618064
# 30778.367882693325
# 29156.39276494042
# 22000.810800265124
# 25422.741679627987
# 9391.034298737546
# 26782.16779268609
# 28089.23934706807
# 18057.027383872308
# 26363.925055920896
# 23629.892614678924
# 114756.18197566622
# 13873.777065145692
# 12834.943193834872
# 132062.03808120647
# 276143.8372002257
# 120821.82060589307
# 291870.0463011102
# 270327.09095039906
# 234970.21725572497
# 292884.11244346004
# 244479.22176604113
# 290010.1298262199
# 256495.39263414743
# 291437.09792921675
# 292529.23031632125
# 282827.65086552995
# 291047.3104871293
# 288613.3737829229
# 151145.076677774
# 277905.9940774479
# 254139.62412654285
# 134018.3177843874
# 265613.40134818497
# 4506.461152452823
# 151380.0340463235
# 19864.364041867873
# 2873.0004390282406
# 38169.93908829537
# 21597.022580352645
# 27704.69028625741
# 17918.79679418684
# 16148.727228469288
# 19489.857700094613
# 20652.402550988143
# 10803.680353232965
# 18953.58631136254
# 16642.11591621495
# 121091.29995405063
# 6210.39475262546
# 21351.80078060433
# 138341.50573791913
# 9033.053545557867
# 272174.44402953534
# 17016.456197366217
# 171767.98628234872
# 2070.6114155382397
# 22581.527499729702
# 58483.82888499678
# 4388.691187701449
# 48220.431353521635
# 4111.665334958078
# 36549.14672783482
# 2167.829341211758
# 835.7041907869816
# 10364.225268412187
# 2577.1895319796267
# 5236.962469122128
# 141482.6766030475
# 15099.862490490086
# 40624.869317661694
# 158708.68452586373
# 28084.215011981123
# 292550.80930282414
# 20717.138456157427
# 1310.6469242331616
# 155280.32075932468
# 16112.227197694381
# 5876.042847171591
# 41850.871143344484
# 18127.892250959216
# 31612.66842499881
# 14178.306603913625
# 19823.522026281487
# 15589.024621894236
# 16881.503838802353
# 6800.628149005478
# 15119.11233231892
# 12643.074991475734
# 125000.06611586106
# 2567.779730106312
# 24479.10844181648
# 142255.70627725445
# 11767.192880813847
# 276069.1459448069
# 4063.3999395267288
# 16908.46484401763
# 1297.8398819021197
# 155695.74515510106
# 15681.23350655851
# 6504.067206014935
# 42219.58151970053
# 17616.993519236927
# 32030.839304471272
# 13693.201622154404
# 20206.306290724617
# 15298.137563856024
# 16493.639713385888
# 6548.672037664821
# 14719.219267296248
# 12359.629523191914
# 125417.01389034536
# 3011.936048789333
# 24726.639849576914
# 142676.8609575519
# 12105.032939488285
# 276478.2097442207
# 4411.3960803154205
# 16562.0167089145
# 981.2285760042435
# 16112.80466823218
# 171070.42092872693
# 1213.4487928881276
# 21758.004579430028
# 57716.56075056788
# 4836.562677796867
# 47457.29901313567
# 2850.6026712586386
# 35747.866952907854
# 1548.5027099854365
# 1349.7102014307966
# 9405.366507067629
# 1179.31550557936
# 4241.705695585103
# 140780.5163012661
# 14242.315198280927
# 39814.76306632363
# 158012.99573023728
# 27257.300611356688
# 291861.21973530325
# 19848.734389920875
# 1439.6483996678571
# 16017.270579203028
# 15645.644676462047
# 30653.301483232626
# 125090.57795586257
# 46652.5469783465
# 25229.973859280894
# 11310.60285839585
# 47997.35442386981
# 5808.110713024621
# 44683.86294546039
# 11003.090396017595
# 46250.42595062408
# 47381.54007768699
# 37487.25515568102
# 45751.89616214325
# 43252.72240331835
# 94916.4029622926
# 32836.53070495904
# 10074.603719375293
# 112230.3997753413
# 20006.747544943988
# 245753.91157325252
# 27005.41312076554
# 47428.54573880349
# 30756.846886794614
# 31092.066552524662
# 46636.435949340135
# 9910.830329309149
# 145575.8739832094
# 25671.635049145425
# 4421.824012853156
# 32390.72488446225
# 27277.16719316185
# 21904.40051713692
# 23733.79334115413
# 10412.507669484929
# 25259.038938174366
# 26430.406366892166
# 16535.7302356481
# 24764.37129598868
# 22373.297835182868
# 115293.53200956476
# 11780.591859614991
# 16331.436405345381
# 132551.71452223993
# 5685.384546040501
# 266364.8736010022
# 5834.755465531389
# 26480.065134514527
# 9738.763864658473
# 10127.779491697358
# 25646.3894964233
# 21227.9875303288
# 32692.332624987666
# 123038.3278398665
# 48725.32206791875
# 27199.532448765563
# 9176.126324120116
# 50101.728816784685
# 5833.026363156666
# 46771.951460817385
# 12976.326856924488
# 48268.43080054203
# 49436.81810379649
# 39508.628246060085
# 47810.59615847862
# 45264.663099737765
# 92874.62168918618
# 34822.57480413178
# 11689.101480184492
# 110190.14805298879
# 21965.914173923586
# 243697.65163977476
# 29059.419505135895
# 49466.722343994756
# 32789.17462026533
# 33151.932283808645
# 48685.34597926698
# 2278.758527277539
# 23266.71803961228
# 31518.60061409291
# 123941.05617993012
# 47399.53452864221
# 25898.725535472448
# 11348.325242108654
# 48707.286905887944
# 3098.6707034474052
# 45457.472750050714
# 11974.599506580316
# 47015.87326529783
# 48130.1720263383
# 38287.409247863354
# 46526.54251023851
# 44097.22453534929
# 93701.4292016061
# 33512.00802354539
# 12601.519005487877
# 110994.18332232072
# 21302.271979875888
# 244681.31200689136
# 27638.24792904443
# 48180.62343221029
# 31505.4369363211
# 31865.42290355122
# 47397.46969170634
# 2925.456533786091
# 21815.650428933794
# 3290.7109095766186
# 11629.513230849965
# 166778.22255012722
# 4734.742478807831
# 17402.78676795117
# 53312.21041319871
# 7752.498948019689
# 43112.41480051585
# 2781.779459137277
# 31326.07436101433
# 4630.663633160339
# 5714.3455052112995
# 5060.088559548526
# 3635.4276830339536
# 2620.5897202278347
# 136490.28356819064
# 9987.81407477978
# 35402.3911642132
# 153736.8488603002
# 22841.83265329222
# 287568.82347934577
# 15418.063966154452
# 5870.264526164805
# 11573.973166318283
# 11145.372669465603
# 4687.064172587803
# 42205.35617873792
# 21229.96797583753
# 44269.41788744199
# 42992.92056827795
# 2338.089263142823
# 157641.76421292865
# 13893.54425316276
# 8294.227413036753
# 44042.83622840517
# 16018.077689734413
# 33991.25559824756
# 11913.627132637457
# 22055.850855766745
# 13406.65720615558
# 14689.023816936893
# 4606.580073327855
# 12869.21287915038
# 10376.484018730398
# 127370.05901915801
# 2625.843916227547
# 26311.411103051065
# 144634.25355517527
# 13643.797197672196
# 278419.29098259663
# 6452.99109832425
# 14730.915843903313
# 2506.145319792625
# 2086.5096238263045
# 13800.132558586933
# 32962.87199883263
# 12107.28050232191
# 35008.85173093246
# 33799.205047952266
# 9297.601352066295
# 53521.39563111189
# 102615.11362995149
# 69520.07962418818
# 47998.52803409529
# 11978.097480647151
# 70774.67925446676
# 23061.154006105102
# 67571.3321880133
# 33804.710284128996
# 69082.20239133184
# 70220.85840859929
# 60338.433409182195
# 68624.60801823012
# 66087.29157778398
# 72626.06246750112
# 55631.325164861264
# 31097.364549798443
# 89945.64320855548
# 42684.50722012827
# 223105.32393710714
# 49853.66373406845
# 70252.92073148837
# 53615.67188703828
# 53974.23570819867
# 69492.62041207455
# 22896.830107656835
# 44042.76973523184
# 20832.456372078177
# 22379.05601165162
# 65089.28994481892
# 55837.50843265851
# 397672.5547349052
# 242974.97966725283
# 413357.8120842027
# 391865.1846743228
# 356505.4150843281
# 414347.3735679292
# 366112.97181163327
# 411502.48944559996
# 378061.37844637036
# 412929.2305063806
# 414012.1987544159
# 404339.6554730358
# 412539.01035098755
# 410106.06235411676
# 273190.6551836521
# 399432.84276322834
# 375621.3855792485
# 256197.43347890963
# 387114.59869217285
# 123556.80796187544
# 393722.93598633015
# 414034.5387490124
# 397605.2588413119
# 398010.972836737
# 413350.566757089
# 367349.8914539072
# 387931.5251285632
# 365298.13067856926
# 366309.25963205035
# 409070.4331765027
# 399943.19224103476
# 344737.62623833807
# 66724.58634775206
# 89230.3042607167
# 82688.40366536738
# 61085.37343570468
# 25252.00557523196
# 83913.70833967393
# 35642.92607843169
# 80763.57991446549
# 46988.491229234016
# 82229.28679784431
# 83375.99903265372
# 73507.32925366021
# 81802.4265530811
# 79270.21130610624
# 59294.53536720818
# 68722.6492652147
# 44475.376825110594
# 76608.57292528864
# 55964.47627937942
# 209724.85994262574
# 62967.28902487497
# 83398.98327619444
# 66768.14391144906
# 67150.28412733236
# 82655.5580494266
# 36154.773508527745
# 57138.26370788339
# 34070.83735892218
# 35376.62934203989
# 78277.28465756915
# 69034.32383133906
# 13419.769119444774
# 331364.56267486815
# 17749.634135126005
# 171993.13609397775
# 2970.2241798434306
# 23374.423585684246
# 58889.05521439263
# 1343.7220985903064
# 48556.2001429132
# 4376.0506580425445
# 37024.71338249541
# 5499.862512604463
# 3102.8837548334527
# 11637.836297512556
# 4326.562917398398
# 7628.098955044452
# 141707.72880181976
# 16204.980598164588
# 41080.77864046182
# 158927.19549846175
# 28786.968734193884
# 292750.8674720888
# 21171.69604993892
# 3887.495573285309
# 17641.60881634299
# 17124.4406367049
# 3996.517760148746
# 47730.21372711021
# 26909.685814477558
# 49838.600372123605
# 48446.404796644136
# 6892.384518875625
# 15486.291917253197
# 70553.4492721513
# 414221.9798765953
# 83709.4091565476
# 17334.707348344753
# 171909.45557250915
# 1807.4588012612585
# 22940.439740089972
# 58698.66339829872
# 2662.7096218233514
# 48397.10208060782
# 3941.089503169349
# 36784.5621898594
# 3639.8448394687093
# 1076.3701872193208
# 10892.558059322746
# 3062.9666910781566
# 6255.56455760704
# 141622.6721260385
# 15577.94081889635
# 40857.01922681028
# 158846.20726364013
# 28414.9200506562
# 292683.7818071497
# 20917.415836408283
# 1779.8851138981195
# 17224.482229063906
# 16799.07950996456
# 2292.577464338901
# 47592.40605975537
# 26681.342954711436
# 49662.98433414449
# 48327.47838986628
# 6192.949736585816
# 15048.627725961966
# 70423.2561765538
# 414162.5811503902
# 83575.45123650643
# 2129.855341154362
# 14627.401013758428
# 169686.91625337375
# 1989.0705625575495
# 20313.280344343166
# 56293.757999435365
# 5770.014457474684
# 46039.538420806595
# 1720.4504236277078
# 34306.93461008992
# 1994.5714566163733
# 2874.4007633565557
# 7911.317526654355
# 648.8717551942696
# 3021.974904237198
# 139395.37362642697
# 12796.666141129712
# 38390.42321586384
# 156632.6129729975
# 25816.707573622367
# 290481.7790415595
# 18379.558458969856
# 3016.7159531179573
# 14536.64142313674
# 14151.126959683173
# 1667.9445231641705
# 45200.34855747168
# 24191.971558682275
# 47254.42639117513
# 45965.83668073345
# 3086.2649691215915
# 12301.590615710962
# 68072.19975726034
# 411976.73852798797
# 81243.48636454361
# 4813.534043416804
# 3586.7207696056475
# 16590.153226620107
# 171407.42064047055
# 513.5399667708299
# 22253.20402632132
# 58117.56910799984
# 3652.6296798142816
# 47821.303433849076
# 2829.738080818435
# 36161.95254428034
# 2819.7440317240507
# 1002.7319799096621
# 10034.653187886839
# 1841.344106487721
# 5257.630446197942
# 141115.95255230874
# 14819.042054470267
# 40234.670111568856
# 158345.35589544414
# 27744.384540395044
# 292192.7119445941
# 20233.199700034646
# 1741.7368492404426
# 16487.531078831784
# 16061.935323241498
# 1287.6174420890409
# 47001.89680692945
# 26032.095894103073
# 49072.70875320585
# 47746.19665735399
# 5173.115240543405
# 14277.709167643756
# 69861.51239102746
# 413678.5139759415
# 83025.94183086982
# 2721.9832453760296
# 1322.6207738014912
# 2402.873439881108
# 23989.919551142717
# 131517.20302206444
# 39991.7269859757
# 18483.02865808602
# 17937.88284319835
# 41415.31703543905
# 8672.089824924333
# 38035.69173431325
# 4345.0346127772045
# 39560.3640224797
# 40720.61156804659
# 30796.451522006737
# 39081.585343056475
# 36581.88338728551
# 101292.97668352607
# 26097.19968955517
# 7657.996389084396
# 118590.92627916165
# 13642.708366471172
# 252242.17972093943
# 20278.975415170215
# 40759.58013008225
# 24046.55170237821
# 24406.05780752766
# 39962.20167523902
# 6767.24384346852
# 14483.354541698298
# 8789.277074021775
# 7665.551459917876
# 35537.33641128842
# 26292.29295987018
# 29582.035050146416
# 373835.1988825442
# 42756.36170275473
# 41124.7780573984
# 40947.840226782115
# 38522.7868308446
# 40343.165201630574
# 71587.61186764372
# 84666.69186968428
# 87575.44465998707
# 65969.51436085593
# 30003.305221057122
# 88806.51390633818
# 40608.4939785412
# 85650.0453069026
# 51850.56947783318
# 87099.19565472714
# 88256.87235718746
# 78375.77452658086
# 86681.74289326939
# 84124.71537865077
# 54891.22325088011
# 73606.12171942621
# 49118.791793172255
# 72167.7529226728
# 60758.877446045146
# 205031.72818201443
# 67871.28454746059
# 88274.46292992147
# 71649.86335421869
# 72033.0763672117
# 87534.24189657158
# 41008.36451303288
# 62044.201458821866
# 38913.493862667856
# 40304.783805437495
# 83156.31529057054
# 73903.04348735344
# 18162.25248617911
# 326689.4817194156
# 5022.392829164317
# 88605.68667174259
# 88461.14230729145
# 86123.68396019617
# 87912.24113959691
# 47634.732178582286
# 16340.848943445404
# 171241.92034771803
# 2756.2473055550236
# 21886.952361333475
# 57880.41320145142
# 5944.979942331246
# 47661.23516873415
# 4128.691239191439
# 35932.82734582392
# 781.3345388809256
# 2242.360929153188
# 9553.919595797483
# 2350.1050074765576
# 4074.610678176794
# 140958.11508959325
# 14331.565263651655
# 39997.22236127333
# 158188.39857771
# 27388.88231395697
# 292031.9892865375
# 20139.088894535664
# 1640.082419913118
# 16243.508858563902
# 15952.705565790387
# 1557.4215794399518
# 46861.579726783704
# 25897.23693809965
# 48877.636734180065
# 47633.64800723062
# 5305.458075507556
# 14059.63240498531
# 69683.98465325688
# 413519.3878886239
# 82830.91712149896
# 5303.146253502533
# 3306.321529439672
# 2558.617555618745
# 2714.2405923784245
# 40177.26444120222
# 87698.3443072991
# 16963.167301615533
# 138440.4510618159
# 32868.74220752354
# 11137.084768076937
# 25328.030901327562
# 34444.41200194358
# 14836.65015643853
# 30964.672918798653
# 3842.391933618937
# 32339.516579824794
# 33578.055294112426
# 23617.753561612662
# 31939.715305287264
# 29421.982339344162
# 108170.83118341172
# 18760.394560299537
# 11412.843482845063
# 125436.2029864746
# 7990.100926180128
# 259224.09995339636
# 13082.411843268914
# 33588.45358085823
# 16864.98720026941
# 17318.820885068035
# 32796.48524789501
# 14326.041955586652
# 7285.70858583637
# 16241.932667329787
# 14800.952227238453
# 28421.60251281462
# 19225.838215164364
# 36953.175889305116
# 380808.1277213602
# 49987.45785464166
# 34120.89718492798
# 33845.01204936637
# 31362.2673717628
# 33219.98855731474
# 7590.850572634075
# 54887.42459610285
# 32965.629984172374
# 13184.339341844032
# 168341.20889793977
# 3868.1428968168198
# 18855.403161065035
# 54855.598487542
# 7452.243691098568
# 44692.03686302462
# 2926.231970104327
# 32881.68597177086
# 2683.953888983564
# 4504.931907363195
# 6365.021904191984
# 2486.249134861663
# 1160.8989066601278
# 138057.0338670164
# 11309.547270176352
# 36924.26464283737
# 155300.453904973
# 24302.516008712046
# 289134.1668207826
# 17065.16029632407
# 4404.464599723391
# 13127.37407317461
# 12805.359945291482
# 3285.970131574285
# 43812.55938047116
# 22845.098576892447
# 45841.7401612805
# 44613.32481970217
# 2225.975299439759
# 10881.241311507949
# 66667.84966947643
# 410631.432619289
# 79842.29376987813
# 6603.05703171014
# 5293.767609119527
# 1919.8057244081242
# 4236.203705148617
# 37131.20750985618
# 84710.10488473094
# 3401.4818182688414
# 29953.739318663167
# 14494.832388119068
# 169525.54651412208
# 2077.015274019091
# 20162.766767196368
# 56157.01949405033
# 5813.997681031919
# 45879.183368885075
# 1671.8761393595316
# 34165.63093991529
# 2108.7067487821637
# 2987.350462913992
# 7780.824132043302
# 823.1438742825002
# 3013.840284260844
# 139232.79166773258
# 12643.88826652569
# 38281.962836950755
# 156468.3015800567
# 25699.366435190655
# 290322.07965928107
# 18221.199170860586
# 3138.256964823533
# 14388.822896372661
# 14005.484035256597
# 1810.56097597739
# 45058.57311579907
# 24036.45809058836
# 47113.0116910022
# 45814.67361684195
# 2959.8375782605913
# 12166.845215701489
# 67930.63764601284
# 411817.6401478174
# 81097.62896239143
# 4857.27818023934
# 3672.409130211177
# 224.28556931254656
# 2498.58084894209
# 38377.778107311
# 85980.19547282993
# 2692.625794575232
# 31209.58603117789
# 1882.8468837189332
# 13864.755527787462
# 168826.75814597972
# 2533.9962135052547
# 19561.286979352943
# 55490.86038626439
# 5832.921355733675
# 45182.25563992576
# 902.1556120599201
# 33499.02592528837
# 3281.4498719315816
# 3708.2613179634996
# 7313.731893471131
# 1705.0361574682265
# 3411.2603725140975
# 138531.7719899016
# 12122.309138579874
# 37641.60148402466
# 155767.54017989166
# 25101.468533121526
# 289621.1283290475
# 17513.10860242104
# 4035.6726545180254
# 13750.97725151443
# 13313.404981551363
# 2759.9186972435737
# 44357.44178700771
# 23337.707618445507
# 46431.2608819714
# 45100.288321988606
# 2331.962034702529
# 11532.199769801791
# 67240.2196450042
# 411118.04196234845
# 80410.84127734398
# 4830.401124029239
# 4132.613035356368
# 1335.1421134368686
# 3007.956060817362
# 37685.67853234312
# 85300.429717901
# 3841.7214801905525
# 30551.8293957282
# 2327.8812365531276
# 1183.8171901333242
# 7552.614481381893
# 162571.66081538782
# 8787.194245380868
# 13268.3330634495
# 49166.338939818845
# 11138.021162696847
# 38902.99459244989
# 6772.991973011383
# 27161.09099811837
# 8578.825559142642
# 9696.891705667194
# 2018.1885749833561
# 7811.81140145878
# 5890.954863938871
# 132282.67830297304
# 6068.853189201961
# 31446.391125703136
# 149530.2730525914
# 18848.251032986187
# 283364.11103020504
# 11201.605543571939
# 9822.465760654713
# 7419.779848847741
# 6958.653162072767
# 8789.936502407032
# 38033.71358900801
# 17019.473404088712
# 40102.23346933594
# 38789.184622737055
# 4229.611006979219
# 5225.303703285157
# 60919.868827218495
# 404878.0115156383
# 74094.06996554685
# 10467.21449258178
# 10046.380900480157
# 7247.556873194975
# 9195.446904723118
# 31353.95944070265
# 78981.06507184029
# 9256.080700493665
# 24232.629070455823
# 6073.813050187124
# 7095.972069489727
# 6366.9836374213355
# 17059.80288891294
# 171802.87592308063
# 2180.424981716586
# 22620.204434998523
# 58517.42569846206
# 4431.612738920281
# 48259.75453845906
# 4209.4668142633955
# 36586.388227517586
# 2193.5971818117205
# 928.5911927431775
# 10408.99895015793
# 2667.187118393314
# 5270.877302837399
# 141518.2317630932
# 15140.38899558828
# 40657.20602985844
# 158744.16260065293
# 28117.44761188097
# 292584.80213678424
# 20764.790482654007
# 113.55957132745617
# 16953.551445050787
# 16610.744990795327
# 1531.8240654649103
# 47466.46431439465
# 26523.939274843095
# 49502.94094224363
# 48220.27106882663
# 5940.938219803599
# 14777.314849506334
# 70287.84287024426
# 414068.074254131
# 83433.28181761819
# 3957.699063344093
# 1841.4529449703416
# 3100.085383279657
# 1848.9484898756625
# 40798.17557748992
# 88307.7318119128
# 1636.6791489209352
# 33626.82302439008
# 4455.484249866362
# 3222.945206759174
# 4129.234396802438
# 9883.669239866756
# 17912.319274418587
# 172092.63604519004
# 3159.0973852817933
# 23477.579982834093
# 58997.761020000806
# 1101.9342507010724
# 48690.928933096126
# 4897.271854557445
# 37153.76186420694
# 5213.88393268419
# 2686.3797045284614
# 11749.294147340539
# 4464.28736163364
# 7578.486988334004
# 141812.80935311835
# 16288.209045843856
# 41207.86806346353
# 159029.88817823914
# 28890.524828085443
# 292845.81750556856
# 21368.634722301078
# 3301.4747800506834
# 17802.428956317417
# 17331.70320073112
# 3865.5347338531246
# 47878.76933354385
# 27081.453844773674
# 49966.69822081256
# 48600.50996734289
# 7174.244640132586
# 15666.270208570297
# 70675.61589880435
# 414314.8070606611
# 83819.19015714734
# 1369.2732744081381
# 1622.7440155761785
# 4951.128784553245
# 2762.600752834067
# 41270.02802202783
# 88708.06370643365
# 4878.9552648613
# 34241.486864186765
# 6624.133499582273
# 5010.929057414125
# 5207.351064535918
# 10745.322169770852
# 3340.0831701397237
# 28084.06418954982
# 127299.45935798503
# 43992.32875663508
# 22317.54337885964
# 14618.269167241093
# 45412.79404180658
# 4142.349591254665
# 42082.154600583
# 8645.101952624822
# 43504.80899277839
# 44696.67888407711
# 34790.436421987426
# 43089.20919168371
# 40590.49311624715
# 97043.31620722623
# 29941.009224183468
# 11088.150032427535
# 114322.77354742469
# 18005.96620998252
# 248069.61106441665
# 24199.07429676725
# 44715.95709946144
# 28028.564463582585
# 28447.67671000258
# 43943.84007398521
# 4638.706548344701
# 18366.703240471234
# 5880.489454979821
# 3964.9367003871075
# 39569.914951856335
# 30363.573897935643
# 25910.584569210223
# 369690.99964535225
# 38838.375323149194
# 45136.94106990793
# 44930.1122096666
# 42518.113362818556
# 44337.95528452391
# 4697.4385590258125
# 43755.44802515845
# 44123.07399259988
# 11183.328661499863
# 41125.249716016166
# 42365.493284243355
# 41688.671056812345
# 35372.18822873481
# 44753.46771400342
# 45258.993763862956
# 4899.791771648254
# 160138.7610389258
# 11535.812623162374
# 10641.910241706144
# 46562.17213827978
# 13964.68585613829
# 36491.63598437731
# 9642.305989867227
# 24581.789930599356
# 10839.452556846249
# 12287.298721782661
# 1990.7012382117812
# 10431.046166406883
# 7765.122728246427
# 129865.40638403328
# 3523.380888803258
# 28785.17758119652
# 147123.90821160405
# 16074.789886042181
# 280921.3648005705
# 8958.856691629828
# 12273.43455402775
# 4915.378918900239
# 4673.650268081956
# 11336.836287940909
# 35523.90676787415
# 14638.874184092834
# 37546.611859948825
# 36352.63121474713
# 6921.583979303759
# 2672.461502424625
# 58376.85512917815
# 402439.1165377908
# 71558.81847064689
# 13378.001290670009
# 12738.445469387787
# 9845.683367288806
# 11919.657987031327
# 28842.536276326642
# 76422.75182884168
# 11500.952951546953
# 21705.409955428862
# 8320.860526697728
# 9717.521657815018
# 9193.26893003611
# 3203.259601804069
# 12316.896132134632
# 13502.149527449592
# 32868.15285791961
# 14678.725213700642
# 169622.02835458217
# 1767.7472943923415
# 20400.55904161139
# 56280.01930685439
# 5127.655102959468
# 45987.998987043524
# 694.9528393596734
# 34300.511609063324
# 3177.3336489422127
# 3079.0124506720445
# 8169.52395706653
# 1311.2929861073155
# 3994.0747141710913
# 139327.8993085145
# 12987.716325291523
# 38393.48752227202
# 156563.80956347793
# 25891.82749008007
# 290412.59681472345
# 18327.802983330235
# 3533.025907562537
# 14582.82141662463
# 14126.652950590213
# 2268.145816785974
# 45141.638868973794
# 24148.40777568917
# 47222.30652950904
# 45891.74827724219
# 3153.386609868346
# 12350.28983625222
# 68024.64252088439
# 411906.09648241126
# 81201.42223848046
# 4056.1768601045947
# 3426.0967755652637
# 1319.5048380706573
# 2261.4242488006703
# 38480.01799641179
# 86090.64778677451
# 3601.4952291583854
# 31369.915259559642
# 2900.4314616292295
# 1271.5298188693796
# 891.7798831509097
# 7190.874208132445
# 3634.848116418251
# 4502.328059246096
# 42496.64559772176
# 10034.30120231244
# 16912.6302902671
# 138945.03065312508
# 32998.01628324033
# 11929.658309038623
# 24880.352293712425
# 34543.19125594498
# 16122.839153387768
# 31011.97384582404
# 3599.5532355911078
# 32541.877547988784
# 33732.72223997116
# 23765.632364460365
# 32045.93520764497
# 29470.120677056704
# 108751.8042890675
# 19323.097255592984
# 8040.727841026307
# 126059.14827150431
# 6187.756767292605
# 259627.57389604338
# 13691.43024036271
# 33768.38336542735
# 17156.033754263066
# 17467.316990085357
# 32946.16082713726
# 13906.847011491729
# 8349.60873708234
# 15939.009739842348
# 15207.524838331092
# 28494.405562130596
# 19237.06662377113
# 36708.51507295311
# 381175.87441999407
# 49997.30290842734
# 34216.3050340202
# 33989.850694448745
# 31498.428638094385
# 33355.245782918864
# 7570.889531281602
# 54820.25296711144
# 33154.33559046679
# 4502.736488101632
# 30067.77401501769
# 31367.264167897043
# 30697.31684548345
# 24379.821452082648
# 33805.863088618615
# 34361.093160017306
# 12117.936636801445
# 21783.426404941627
# 31482.39866799711
# 11380.803292735243
# 166483.755399577
# 5674.103877094427
# 16975.460732189076
# 53013.75314213486
# 8985.088666667805
# 42844.282490290454
# 4344.182588417456
# 31037.44351356185
# 4435.728140689721
# 6302.79499576578
# 4518.9816377912
# 4364.339019761401
# 1517.3496230050607
# 136201.29366228642
# 9413.89967106744
# 35161.19003823258
# 153444.64777509213
# 22484.005792174055
# 287277.22507653007
# 15269.426676056946
# 6168.82620182818
# 11301.315571379848
# 11036.606123648313
# 5162.345319311008
# 41990.6015972662
# 21022.41155455214
# 44004.71857342415
# 42783.66321832527
# 2140.2248584164095
# 9101.702333165847
# 64831.34970769634
# 408780.6675525357
# 77992.53028811577
# 8214.137631905387
# 7021.732460877296
# 3754.4652236183206
# 6044.549871561052
# 35298.55977201068
# 82858.35472295561
# 5142.528749645902
# 28091.595503474855
# 1962.8695442400199
# 3659.9715674992176
# 3683.365942694986
# 4573.295992831873
# 6211.141926274688
# 8224.02350784907
# 39268.36249393844
# 6486.824636102915
# 4472.516220256612
# 28255.838913296244
# 16284.601650408977
# 171138.91155476062
# 654.7136567584813
# 21917.50158695098
# 57849.53548934034
# 4214.328245802109
# 47541.01156544001
# 2740.34803948098
# 35879.77286870824
# 2207.3225807398476
# 1048.1151518222798
# 9650.019292817904
# 1426.078315461317
# 4753.116739614078
# 140846.47584183613
# 14436.220394279064
# 39989.95515851439
# 158075.12170990658
# 27453.268840416502
# 291929.4255288202
# 19944.967506405377
# 1512.3372186098138
# 16167.981832183188
# 15772.038928557182
# 718.6687202809618
# 46745.88593953048
# 25746.961621600905
# 48805.961811723915
# 47485.80706406348
# 4853.16682398531
# 13968.753248677807
# 69604.16097243282
# 413417.94056781096
# 82761.70930669428
# 3332.6414153536043
# 1758.0434874546936
# 1945.5259022721223
# 650.3170574059267
# 40074.2770313222
# 87646.9957373825
# 2173.5169870746445
# 32918.66997214863
# 3731.935555391217
# 2042.54107431486
# 2744.3230106074047
# 8901.192922118818
# 1623.734322535156
# 3282.525237209481
# 44051.94978729796
# 11561.858130738769
# 2118.330097987107
# 33088.84502555706
# 5551.464504793716
# 14403.177493138432
# 169409.96773112647
# 3404.555964986407
# 19957.08445400372
# 56017.80750330488
# 7088.715224872681
# 45788.07011300776
# 3386.5850578773293
# 34042.25044778702
# 1420.8009977366619
# 3716.252155325742
# 7551.719916516382
# 2161.2385653514357
# 2131.2680466192314
# 139123.36566625934
# 12365.750553517391
# 38162.27897073236
# 156357.8492130659
# 25505.445313421213
# 290206.552597462
# 18220.12010849432
# 3434.3585750730817
# 14296.071261842091
# 14018.123383399161
# 2491.2006302206905
# 44990.64011934788
# 23990.007237592148
# 47005.84418475227
# 45760.18749881271
# 3522.18096705243
# 12113.290408428868
# 67827.33338010861
# 411701.6792102023
# 80976.48266020941
# 6280.280766365537
# 4656.592943336642
# 1773.6531385680273
# 3669.740357727899
# 38295.073700961424
# 85846.09932839786
# 2175.822177015947
# 31067.28220949174
# 1417.513045213338
# 1799.093154219204
# 2789.6463974607036
# 7333.8839900060875
# 3472.89360535512
# 6144.155440514306
# 42241.50904683408
# 9523.030837423155
# 3068.0507033658782
# 31272.459027676807
# 3063.9234514037435
# 3061.226360794092
# 14072.855339426564
# 169226.21329312195
# 3069.422961957965
# 19759.324149341424
# 55745.544064493486
# 6783.760255607537
# 45577.60254348036
# 2571.687732846973
# 33773.39774468926
# 1919.7756225712797
# 3670.9549407879454
# 7275.270703245248
# 1665.747740313218
# 1901.1761392757014
# 138940.96866848716
# 12217.807846717526
# 37790.733923698994
# 156183.4955584863
# 25191.183636241472
# 290018.9251667954
# 17940.665306847226
# 3582.2034058594118
# 14019.090251783782
# 13679.94311326239
# 2407.602082407045
# 44695.462574019264
# 23727.85464890425
# 46729.953296839674
# 45495.65795878675
# 2838.145525105488
# 11765.016655063353
# 67554.0686223135
# 411514.5310007996
# 80731.36828545493
# 5906.246476270332
# 4508.426779936236
# 1199.8653034039025
# 3418.835837713183
# 38017.69915976629
# 85600.0429631868
# 2615.1089777970833
# 30848.842322171047
# 934.4180424618363
# 1249.3269013333688
# 2090.05369462889
# 6890.916891220988
# 3637.521160335602
# 5914.602995993768
# 42016.96608902014
# 9224.827894492577
# 2395.5131709201246
# 30951.29273813377
# 2892.666115327803
# 2903.8309239950268
# 1006.9546672611423
# 15657.659058434234
# 170606.51702060353
# 1500.8093656131775
# 21272.19298220725
# 57276.837986965445
# 5239.029073247148
# 46987.020136940584
# 2651.256903388334
# 35294.907803700575
# 1286.5892896898747
# 1859.7265004153612
# 8916.623327923478
# 940.9577427742354
# 3799.8272609508053
# 140314.47265184333
# 13732.98713568025
# 39415.99617137605
# 157545.2983584862
# 26826.431756153732
# 291401.827816032
# 19376.147507593723
# 1868.4256398326988
# 15540.891575602598
# 15184.27621215345
# 597.9704932826929
# 46196.0239887243
# 25177.63508052349
# 48240.98018376562
# 46944.303280068896
# 4248.721203607896
# 13341.608745090885
# 69052.66298735722
# 412894.00968502945
# 82208.03775877203
# 4377.385879353111
# 2758.767619331145
# 1234.486232751238
# 1703.8034689204567
# 39511.99365828386
# 87088.62952673344
# 1578.1667621605795
# 32323.822298895273
# 2801.141174852733
# 1348.2472632856293
# 2392.7848682125755
# 8326.898672182302
# 1952.419310741822
# 4293.080071690213
# 43478.17835511171
# 10862.176081149524
# 2062.51179627899
# 32511.64000014906
# 4649.691039124208
# 1078.7756637950822
# 1993.4640803476075
# 1955.6325637543716
# 19514.8501859958
# 135937.60778938315
# 35514.6403601501
# 14024.137395082294
# 22393.390455160068
# 36987.48743359812
# 12622.963198827989
# 33557.34718383086
# 1071.6125433077034
# 35083.29586604603
# 36250.326567973614
# 26315.198840785746
# 34600.37232732659
# 32109.843761400196
# 105697.56214842411
# 21623.120324616026
# 8541.039443274625
# 122987.55310254346
# 9501.452513593245
# 256679.8281756257
# 15794.448587679708
# 36291.29918515766
# 19558.84036229686
# 19919.225799759864
# 35483.36351624356
# 11229.469591607927
# 10013.077644572
# 13265.842398539933
# 12037.397934630926
# 31053.631021950667
# 21812.651840587794
# 34070.99964502768
# 378260.90307566314
# 47236.83117309322
# 36678.52402863667
# 36486.196779590224
# 34039.19348136751
# 35868.8457078327
# 4490.470826333245
# 52119.0681286521
# 35704.74983784002
# 3488.2400294753593
# 32650.01235325124
# 33893.07828204664
# 33201.963247712825
# 26868.182496820984
# 36330.88632484067
# 36828.89546512823
# 8757.772129293715
# 24364.879862401118
# 33999.198226645276
# 3765.4520308705887
# 30819.78543596822
# 35596.987565675605
# 33815.92886288978
# 33536.77247113059
# 35031.239231487365
# 8689.079088372686
# 146864.92972253799
# 24370.952539839534
# 3356.5052285231245
# 33707.76301224762
# 25996.263938587344
# 23190.869108654675
# 22434.533718349372
# 11722.33635578703
# 23968.547517311705
# 25135.677121963217
# 15258.380387433448
# 23465.688785035436
# 21097.9807760116
# 116579.93720935783
# 10510.021161824154
# 17493.523048418992
# 133834.6187272652
# 6247.147809401514
# 267657.8191446219
# 4526.367049186998
# 25188.336230334568
# 8465.224373724684
# 8852.914246675578
# 24349.355712035504
# 22542.856260970824
# 1320.596744319418
# 24584.83404218493
# 23124.791444041286
# 19934.372802250273
# 10848.451233511398
# 45360.171072508725
# 389219.2753866841
# 58452.33130107962
# 25617.735666140838
# 25387.06269174947
# 22893.045589578207
# 24732.867373627134
# 15800.331507697938
# 63360.25016865229
# 24608.595392580388
# 8585.93648371015
# 21556.4067665883
# 22735.857775911776
# 22033.9896519875
# 15720.675932108785
# 25233.224621360703
# 25795.04299000655
# 19675.356128060077
# 13374.13678069686
# 22845.816225483934
# 9564.182728918266
# 19738.441097460436
# 24446.292191291323
# 22699.483683996234
# 22437.628196507412
# 23878.460175400334
# 11329.066446784995
# 14636.798746244585
# 140832.57845102675
# 30648.05911455849
# 9353.164193371225
# 27207.41083108997
# 32173.516193721323
# 17395.12506020063
# 28674.62326823408
# 5248.4511893451445
# 30240.136472918555
# 31400.541159334152
# 21460.973211374883
# 29727.488338645253
# 27252.165082097716
# 110588.32920378011
# 16855.311966062127
# 11188.071015167376
# 127875.84375763209
# 5321.151914331335
# 261577.04561241023
# 11003.806032391563
# 31449.850201563186
# 14715.644418340535
# 15045.616187110443
# 30622.86208102335
# 16051.679254355602
# 5383.5275934961555
# 18116.4270881071
# 16915.668054894995
# 26172.324610141168
# 16932.620764036135
# 38932.3004531534
# 383133.3888387685
# 52125.2346738348
# 31838.285866370577
# 31641.066175574073
# 29169.440019019872
# 31006.800148661576
# 9375.72307713362
# 57002.21107634183
# 30864.988690828883
# 3407.1446111223363
# 27787.669158504086
# 29026.184266623928
# 28329.16300708035
# 21993.041670552855
# 31490.666752490975
# 32003.22068363353
# 13616.971110452232
# 19504.037305135604
# 29123.561530316565
# 3180.195666302008
# 25969.87854126365
# 30737.668777047205
# 28970.428492972085
# 28670.941818671177
# 30173.24834146904
# 4909.513869213045
# 6657.1504805522545
# 12444.739125610782
# 167465.36266118087
# 3971.126612604808
# 18209.852286985475
# 54063.73519591478
# 6871.075060063586
# 43813.59173249655
# 1829.4019766893869
# 32081.111830551636
# 4465.958413356105
# 5103.0253435881705
# 6036.903766558147
# 3079.7350014652648
# 3299.9468843617033
# 137174.10434049318
# 10855.158882918104
# 36177.34190048875
# 154416.7973993551
# 23666.3817007532
# 288255.32654648885
# 16128.14769486256
# 5397.763554185685
# 12368.74205369113
# 11895.820299457391
# 4172.13342276084
# 42926.01995262406
# 21947.812808720606
# 45006.930054666715
# 43693.130068012164
# 1122.042263029367
# 10114.630435370002
# 65815.05302517398
# 409754.87163317733
# 79001.2002321198
# 5943.2929615021685
# 5462.306550294676
# 2627.7899316862477
# 4430.338706754878
# 36265.52771310253
# 83887.83900919132
# 5085.751144314867
# 29172.62569290582
# 2559.1808010660466
# 2490.3781782392307
# 1525.6075112174044
# 4956.804054330258
# 5482.268235340113
# 6361.218714192884
# 40301.03854805672
# 7844.693837495799
# 2276.1899208334853
# 29252.459143851553
# 3115.1901490158803
# 4201.2560053877805
# 3610.0702145627283
# 2830.282090761939
# 3790.9869973073305
# 31784.075075857363
# 20647.28227036371
# 26901.926149105977
# 1989.698904777815
# 153641.74323015596
# 17761.095308325068
# 4303.555144215745
# 40181.07262743388
# 19703.65640666297
# 29981.86816030368
# 15820.818444266239
# 18153.537166238424
# 17241.30057668926
# 18523.209343609895
# 8443.486486489295
# 16774.015297386417
# 14276.158273887671
# 123365.3551210012
# 4007.493480708245
# 22868.26425088439
# 140625.04927542858
# 10175.335385573979
# 274427.239294718
# 2628.026978907747
# 18548.980114564976
# 1671.4635065542402
# 2221.6321264689486
# 17671.212057356133
# 29089.925271246102
# 8114.6599431504665
# 31120.45918153727
# 29850.634989507525
# 13226.314343326942
# 4037.788937665059
# 51947.99399849828
# 395965.7065142265
# 65104.26928467747
# 19242.356977596464
# 18852.69588948737
# 16195.677040761266
# 18133.178467865688
# 22380.188368683346
# 69984.09145079089
# 17889.721528040875
# 15218.82660018614
# 14780.883810460005
# 16049.651311795176
# 15406.64104182643
# 9066.66992531063
# 18592.770461797245
# 19399.108215529548
# 26376.333911831127
# 6526.450335429307
# 16233.419075569696
# 15494.951261181926
# 12949.697780157427
# 17819.597005797557
# 15950.22491253565
# 15673.133217192675
# 17198.64379620882
# 17893.974914809074
# 6859.613125991016
# 13050.405698330045
# 14014.975728110261
# 16145.555595652797
# 170958.63812938172
# 311.99060298535835
# 21808.22632306917
# 57688.347138173245
# 3895.126818221789
# 47361.22229585292
# 2268.742362616192
# 35720.345944425746
# 2915.0984257411337
# 1615.0463730477252
# 9609.969008407646
# 1562.8809049598765
# 5025.103987969148
# 140664.31063154314
# 14378.699274982813
# 39832.77551534974
# 157893.14181409343
# 27335.221286158594
# 291746.8783255852
# 19755.772494196393
# 2274.2529966910392
# 16028.72151578565
# 15592.21293536771
# 1449.0060701365906
# 46557.10741186053
# 25564.634659394265
# 48633.363549389935
# 47289.921098332416
# 4695.484029704966
# 13826.38560447716
# 69424.6774044987
# 413235.34991748224
# 82587.42395568523
# 2851.7229131808062
# 1858.718731113438
# 2056.7046881891206
# 667.0419539244149
# 39894.835533389225
# 87477.90149909632
# 2982.9386947931034
# 32769.088044372744
# 3947.5208541814955
# 2114.236820699432
# 2450.7752052546803
# 8698.821722653427
# 2385.2343648502265
# 3117.798883612247
# 43887.74811876873
# 11491.183333884124
# 1675.086778372516
# 32921.15084299037
# 5706.4605621722685
# 843.6619909863631
# 3530.5443282784477
# 3187.511421072446
# 1659.2497418684447
# 35417.89669666007
# 24262.32257351561
# 30553.814214354035
# 3888.6957911619133
# 17677.355288966908
# 21147.496545850154
# 134699.0896363036
# 37250.81605500047
# 15909.414592715842
# 20598.915240988685
# 38776.283633168314
# 12356.184656141568
# 35284.458998726055
# 2301.039182776505
# 36751.26376501348
# 37966.579386645964
# 27978.702648420574
# 36297.52570211819
# 33688.91417034219
# 104520.2331798012
# 23431.529679308358
# 5637.151112617598
# 121830.48421498705
# 10287.943629422987
# 255368.9737226873
# 17802.136308815734
# 37987.40520240058
# 21342.488052800763
# 21694.067303440734
# 37183.173747609806
# 9733.028222325136
# 12211.454001368567
# 11685.344704524556
# 11201.51499347037
# 32751.789024239817
# 23478.029680790674
# 32448.273420700934
# 376927.32414668397
# 45724.82062945525
# 38470.147875517694
# 38228.03156616152
# 35743.72206157574
# 37604.20502055642
# 3799.087701428723
# 50540.09184053874
# 37362.16122813208
# 6068.939631196439
# 34297.090508090376
# 35611.03226511401
# 34953.02809327804
# 28628.283361585673
# 38023.12400687079
# 38594.968451624045
# 8263.681143025045
# 26001.82966075016
# 35744.49451855471
# 4318.321612214336
# 32466.11987914205
# 37330.15872200297
# 35481.332685392415
# 35186.0768824479
# 36744.049324028376
# 3080.852855357369
# 13495.578471496905
# 6896.665642239567
# 33518.64059009793
# 19674.855001001924
# 37173.270175782185
# 17319.543683278876
# 171914.71668863908
# 1790.146064354968
# 22924.660963907332
# 58694.28031233051
# 2795.891725160997
# 48398.79318734677
# 3949.4072599089095
# 36778.80917759644
# 3520.051620549926
# 947.19347389074
# 10858.05022968497
# 3007.2959330293784
# 6173.091801520793
# 141628.3110498587
# 15551.655925346578
# 40847.72262539626
# 158852.21705776206
# 28398.055280177992
# 292689.71811538126
# 20915.346996812597
# 1633.0851439498585
# 17211.043679636892
# 16791.951070024083
# 2197.51091599864
# 47592.69043651458
# 26679.506006577085
# 49660.546665562746
# 48330.58563148554
# 6169.529834249785
# 15033.06197897986
# 70423.28979668561
# 414168.7169125012
# 83575.71266279809
# 2279.1826911313237
# 152.4733793127297
# 3531.796765090105
# 1296.6574405975225
# 40946.376866718194
# 88460.31199209782
# 3170.427963599914
# 33838.631807029415
# 5221.2512999199325
# 3621.9477907404
# 4122.250855965126
# 10037.916979146801
# 1693.055578558381
# 1743.0603468376187
# 44927.74881569287
# 12709.705754361188
# 3426.809021811592
# 33983.69936963325
# 6956.834963363851
# 1693.4628444879374
# 4558.7565486101785
# 4429.695667345512
# 2672.2590602691466
# 36484.13865398041
# 25385.45654761883
# 31638.992234345842
# 5459.237232897614
# 18840.395820177342
# 1861.6741687035724
# 38220.77913686762
# 14316.101608225646
# 169364.84186958504
# 2887.6021566747545
# 19927.061583259525
# 55972.00597848795
# 6618.902451304652
# 45726.05327871523
# 2683.0478931964662
# 33985.886114910485
# 1575.6703005409495
# 3420.30412636114
# 7494.897484102914
# 1573.614044158078
# 2266.3189973965677
# 139075.5871662227
# 12354.266103984459
# 38101.89526256263
# 156311.31891870988
# 25469.435388165464
# 290162.9939894335
# 18107.648033844816
# 3295.2647204355126
# 14211.675381188374
# 13890.999151645148
# 2157.568150188153
# 44915.10707531636
# 23900.379217496098
# 46946.292858159555
# 45681.55160546541
# 3102.9155232299568
# 12005.476634382427
# 67769.21443898979
# 411659.4919577003
# 80927.69940171477
# 5753.701355232595
# 4282.810965453477
# 1095.842522070311
# 3213.3585315504483
# 38224.03325896049
# 85802.30448988357
# 2317.230919354177
# 31019.154117028185
# 1255.1159803210796
# 1103.181808757018
# 2094.633663886122
# 7093.757614319798
# 3352.8179932233547
# 5724.259020725591
# 42189.499448973154
# 9462.434692248271
# 2368.7773498959195
# 31201.459233815607
# 3095.206865529694
# 2641.1979247008308
# 709.1683216471749
# 603.9562050569924
# 1624.9926201022402
# 33741.7063087724
# 22604.80910878821
# 28885.29950891973
# 3025.411944747836
# 15870.67596379502
# 2987.005461380674
# 35426.613014078044
# 4201.042287377738
# 805185.6257705088
# 650433.464418381
# 820560.6094677899
# 799243.748490961
# 764732.6949142333
# 821492.7182687495
# 773475.570215139
# 818778.5384217383
# 785792.2876833616
# 820134.2240090502
# 821197.4644730857
# 811700.9449696945
# 819787.157056248
# 817465.5762886356
# 680448.1704014777
# 806694.8649629673
# 784046.8541833641
# 663156.6535686826
# 795034.2596701584
# 530953.9629520426
# 801056.3309026932
# 821214.3974190657
# 804988.9780484261
# 805428.6869097705
# 820561.9162571325
# 775272.4287944484
# 795324.552005616
# 773238.8411492023
# 773964.5652329244
# 816382.8613006216
# 807404.2647759494
# 752984.2628203543
# 411922.4940875798
# 739596.0701087867
# 821382.0749020979
# 821331.8827154338
# 819215.7476718198
# 820871.948539009
# 781569.6837420318
# 735055.9125700215
# 820725.2901100614
# 788260.6902886676
# 817925.9910719086
# 819042.795191101
# 818343.5287395109
# 812195.0627507541
# 821249.2159671889
# 821469.6545785106
# 777235.9030432511
# 809857.2880950109
# 819136.8641582383
# 789061.6761462918
# 816076.2693767177
# 820599.9020374349
# 818927.3300113421
# 818801.0347316395
# 820087.2394784536
# 785925.3084188886
# 796585.3937869642
# 790786.1348729013
# 817037.1735143564
# 803383.0758740809
# 820418.4770527693
# 784847.8202407579
# 821340.8491334262
# 818888.9050224777
# 12733.119767034677
# 167843.8630758416
# 3968.3221810775026
# 18390.499932260864
# 54417.357073163876
# 7425.602441477596
# 44187.23991100069
# 2700.3935014604003
# 32425.36665383121
# 3171.6565669419565
# 4739.891710442509
# 5935.015006059957
# 2671.1412378648342
# 1597.4775293405512
# 137555.07201374776
# 10845.215495895183
# 36548.800012374755
# 154795.4692350756
# 23918.759763795973
# 288640.627979693
# 16536.600906569583
# 4729.158574559548
# 12638.94619719766
# 12297.810893514921
# 3573.7083012778735
# 43347.07129847041
# 22336.197550163273
# 45385.6631973768
# 44120.855584226505
# 1603.0064430550317
# 10414.124673100345
# 66211.68865105748
# 410141.0242683216
# 79379.09079230842
# 6563.79489471022
# 5430.023782741082
# 2044.5638185921964
# 4369.367583388588
# 36659.6989759099
# 84254.83794754936
# 3894.938276322626
# 29474.67412562911
# 758.114312383578
# 1933.8142037443163
# 2001.6957037194738
# 5483.263765431036
# 4790.182692395517
# 6666.281742002012
# 40644.15334337914
# 7895.0516218117855
# 2746.079143183643
# 29630.971349497206
# 1753.403615809514
# 3901.5819769979094
# 1947.0013435126962
# 1452.8964346711475
# 3062.304218021912
# 32175.007771866418
# 21041.25672730229
# 27311.508749528864
# 1970.6823340702367
# 14299.490823083524
# 3990.1053006869456
# 33863.72510596592
# 5374.5110657165515
# 1632.8182552823173
# 817405.2548196368
# 3764.2521376567424
# 159004.92476091793
# 12510.227582605567
# 9571.844585418858
# 45459.470808512415
# 14752.859596449807
# 35343.255001784084
# 10556.520452240147
# 23462.68431942329
# 11977.944107176498
# 13302.051520471075
# 3170.1467316000276
# 11467.194007974662
# 8969.689227745212
# 128728.44130899792
# 2834.928453403489
# 27747.457749922505
# 145987.1986579767
# 15060.098248578022
# 279788.4032230643
# 7739.13766859851
# 13333.440814754656
# 3743.006192311185
# 3402.0651342813126
# 12392.021105730524
# 34382.4934967842
# 13458.087726458078
# 36422.67512096054
# 35193.25189914014
# 7905.561505086554
# 1454.2381039856366
# 57252.49734180743
# 401310.48264074203
# 70436.29752404634
# 14191.471252969885
# 13690.120686193593
# 10889.833605581875
# 12896.620922289241
# 27700.81720689809
# 75308.00215635708
# 12639.254107846626
# 20583.047680398962
# 9457.160436298127
# 10752.764452592093
# 10142.409326717932
# 3871.3115203524385
# 13380.452973937661
# 14362.20605615006
# 31737.84909695746
# 1316.3061959320407
# 10973.085108569796
# 20671.919332725985
# 7668.132217714513
# 12571.218575981247
# 10678.154132279975
# 10345.669075333792
# 11924.147256252796
# 23217.464831469202
# 12186.02609458037
# 18346.909513046467
# 8749.054032911075
# 5366.928196401072
# 12445.523910836364
# 24902.05186029721
# 13671.24831869782
# 10575.01211774857
# 808725.5437271954
# 8985.61977353264
# 4432.029783820711
# 159151.92883758468
# 12205.03781490659
# 10082.690375906132
# 45740.917465738676
# 14166.967095238899
# 35496.44675249035
# 10155.885492999332
# 23750.953600063836
# 12070.192529084909
# 13104.312233261538
# 3856.302917038933
# 11297.413114302088
# 9281.56078040063
# 128866.86329154421
# 3944.851228730083
# 28123.041688383462
# 146120.28759762523
# 15601.385744726496
# 279935.14279960893
# 7829.856750625167
# 13246.226448784193
# 4286.935181805127
# 3630.7774230254363
# 12265.872376658273
# 34577.931944660835
# 13617.187022304337
# 36664.318081661506
# 35334.56829102945
# 7719.058473365532
# 2391.402297096365
# 57469.453664925764
# 401458.22115328186
# 70650.71520642341
# 13603.891197272676
# 13371.207706034611
# 10748.74028540644
# 12600.766419204136
# 27913.090255397732
# 75540.98400462794
# 12731.603727019341
# 20864.388826191123
# 9567.931629755363
# 10598.067756423725
# 9819.076762273431
# 3526.566675396645
# 13304.55245454643
# 13898.931793428324
# 31964.273522139974
# 2707.1229640276247
# 10610.239947286911
# 20973.15573257533
# 7964.821242468824
# 12345.436044880906
# 10826.738003715218
# 10395.432255702372
# 11819.154670252043
# 23431.40997375444
# 12325.934189436559
# 18552.881038887754
# 8376.489681720546
# 5832.362121984556
# 12102.36808345245
# 25226.014395506245
# 13372.758758904734
# 10608.19507250304
# 808826.7002092286
# 8999.801346392325
# 1862.0487984266197
# 18263.080709537026
# 172154.30180371404
# 4032.847382367845
# 23800.384913440073
# 59145.23562840061
# 181.9940300499465
# 48831.69855105081
# 5520.481984620806
# 37351.26356218309
# 6230.877354481576
# 3724.502423655447
# 12300.44587787213
# 5343.833594983314
# 8434.819584459323
# 141878.61927386947
# 16737.086010263585
# 41395.032571718606
# 159091.20436352023
# 29170.271495279216
# 292891.72435437114
# 21624.634058413132
# 4355.444499008511
# 18153.115632283167
# 17647.553572333927
# 4851.685261437905
# 48014.48594241902
# 27300.08338243587
# 50116.41609003055
# 48724.946536724805
# 7801.985406902295
# 16046.195020060755
# 70787.40095175683
# 414354.47564079234
# 83924.7007071416
# 1482.632867212684
# 2654.276459386425
# 5809.375497600675
# 3689.066172367565
# 41432.31106558218
# 88816.3495551573
# 5923.676411396903
# 34459.626504183456
# 7475.400546316203
# 5855.099683675286
# 5896.67360824893
# 11181.460676122475
# 4394.18133335484
# 1056.0440878478696
# 45426.60466503885
# 13988.161426035404
# 5199.862936094972
# 34561.01871992292
# 9002.835514324346
# 4239.3123060811395
# 7095.798469388193
# 6807.062507702673
# 5256.574953558368
# 37006.243805156
# 26019.86426177134
# 32193.957058100234
# 6936.552370974606
# 19726.945519131386
# 3952.155172127518
# 38791.927868310944
# 2782.75351692447
# 6638.430376394896
# 821498.566748698
# 7457.133790766479
# 14781.396618622757
# 14210.192234312364
# 102335.23777750277
# 53048.213100650886
# 118074.29999484077
# 96506.5854614431
# 61563.73514185563
# 119194.38943720308
# 70649.15825221158
# 116205.20584568322
# 82735.91097522761
# 117630.47748395779
# 118746.73152605476
# 109005.97802949182
# 117235.18426968668
# 114800.41741846765
# 22835.52819966446
# 104083.92992742459
# 80875.18349923023
# 40155.57193608307
# 91933.57077041506
# 173837.90593190485
# 98349.48540000197
# 118769.36442016342
# 102244.84860959247
# 102659.77942774128
# 118058.00584625034
# 72094.96652016582
# 92540.5428405372
# 70045.77795060354
# 70908.58817138532
# 113750.20556264411
# 104604.10540093119
# 49832.44588360443
# 295770.94848169346
# 36539.124693459264
# 119021.28824562614
# 118920.72114253271
# 116666.52877246818
# 118402.82956374208
# 78486.50026446459
# 32267.189061360652
# 118233.47095181671
# 85403.08148378543
# 115314.69466526895
# 116506.3737397468
# 115809.30895587493
# 109543.83408818977
# 118804.76930290626
# 119126.60361140704
# 74258.59393625299
# 107103.51324469343
# 116606.53249180061
# 85932.05662491542
# 113457.81549084953
# 118132.53757465043
# 116392.30077779267
# 116200.56162527586
# 117593.99287880657
# 82900.64389980517
# 93833.0012429082
# 87796.95373531981
# 114443.47632410393
# 100605.38362406658
# 117952.92788427998
# 81694.0258840782
# 118924.97852516083
# 116345.36954578783
# 703266.0432385674
# 114818.89079892781
# 105968.35683495247
# 106122.80820106062
# 119204.02256468704
# 47110.98809924427
# 108540.33156205511
# 62714.9357735692
# 41149.688792853485
# 12246.726964172862
# 64018.812209010655
# 15528.377211534438
# 60881.8240238159
# 27989.02462158634
# 62198.97275964868
# 63383.02229653623
# 53637.67126274972
# 61855.37500532405
# 59420.82736779536
# 78239.6126802593
# 48647.127513451414
# 28387.866035586136
# 95445.06828633466
# 37298.34938863699
# 229356.2180589381
# 43032.56725848655
# 63386.25556480365
# 46918.01701582054
# 47385.39939411472
# 62664.38413501459
# 18598.97973191531
# 37280.41426476345
# 16757.635110260828
# 16632.211301963664
# 58397.897460681976
# 49336.887616671316
# 12945.705444420297
# 351029.7496539936
# 22213.099178875542
# 63792.426423573386
# 63598.49222830299
# 61273.341840133915
# 63047.27346646634
# 23944.10966852648
# 27091.08739415621
# 62812.039823346226
# 30180.941446934863
# 59914.56943471675
# 61107.7071348198
# 60438.79614306
# 54205.10718161944
# 63422.60979701838
# 63889.036763931574
# 19357.870406154994
# 51777.22375774586
# 61253.31069138137
# 31456.014311770527
# ...
# 8389.757416493123
# 31123.049658833803
# 105227.38123748402
# 50160.09719782746
# 120976.09577436886
# 99387.35373032869
# 64420.194990010394
# 122109.26523914892
# 73549.49549664289
# 119112.28001122229
# 85624.03640333336
# 120513.2007237208
# 121643.05570889765
# 111892.3749178851
# 120132.0578764173
# 117680.86224522979
# 20007.163570856916
# 106963.7449079997
# 83743.11405810712
# 37314.58992606506
# 94807.92872614294
# 170945.8830409652
# 101250.83389359154
# 121659.26504199776
# 105137.54577383838
# 105558.65784242816
# 120951.30339056639
# 74997.18574354143
# 95441.06566558627
# 72936.16949331916
# 73819.78412477957
# 116648.52122972498
# 107498.40160896424
# 52705.56947652244
# 292829.07176827866
# 39374.24038901493
# 121937.15985828517
# 121822.55423322743
# 119561.48803348202
# 121303.765433993
# 81385.81864432532
# 35049.37782066299
# 121115.72861302405
# 88290.6622459083
# 118201.84307574248
# 119402.2946469618
# 118711.55874586935
# 112444.98513871878
# 121693.98740477582
# 122035.39893049827
# 77150.09183957326
# 109990.40565407074
# 119510.87352957341
# 88824.02711273948
# 116340.31533319509
# 121030.08414773674
# 119274.40519514403
# 119089.25493233296
# 120486.13867766804
# 85799.84675980403
# 96733.6296554121
# 90696.40928915283
# 117347.93889390324
# 103497.760175697
# 120856.01864210551
# 84578.4479125344
# 121825.86078685547
# 119233.2651107701
# 700367.8791413056
# 117709.62306875597
# 108861.12978259081
# 109029.38866615375
# 122117.99282927539
# 3103.6331885182854
# 58454.9575379981
# 117557.80526371497
# 28175.61555841274
# 121028.67335326652
# 121951.23129588591
# 41606.93267978902
# 86910.4841770667
# 12345.654437889529
# 43107.972264111646
# 107619.74730938257
# 65447.68086751112
# 121792.50796192628
# 115915.03859522931
# 121322.02889276469
# 75897.75695645246
# 117102.0288672269
# 99497.51468373892
# 122052.1706674603
# 91358.60406389742
# 139465.6445766493
# 22574.247813378333
# 155397.82819902175
# 133828.95640866563
# 97858.05531032421
# 156501.52668828043
# 108228.48656473566
# 153479.46872122548
# 119731.03660671103
# 154957.82557935666
# 156073.19121499054
# 146253.50919374457
# 154531.00555646807
# 152008.0167073339
# 21570.738823569045
# 141463.52516873358
# 116756.86702377864
# 18851.921461490056
# 128631.99528849611
# 137873.6390314955
# 135700.50581216588
# 156098.14170859155
# 139514.64436457693
# 139890.45315715304
# 155376.80428368814
# 108852.82624748524
# 129871.59531857833
# 106787.59979930571
# 108076.77980390226
# 151012.72955155734
# 141776.34803568176
# 85983.1287157063
# 259558.5759531454
# 72751.59837275352
# 156339.84406642066
# 156249.15386795186
# 153976.31914856145
# 155729.0199862589
# 115492.66303656051
# 67894.20020928998
# 155551.1949390553
# 122723.45640318
# 152583.25108102782
# 153830.51050492036
# 153136.42859929526
# 146829.75513221938
# 156131.11026851452
# 156441.8442029515
# 111557.37345425197
# 144303.77176798927
# 153920.08889257014
# 122688.68288045899
# 150735.40093235037
# 155474.26558055053
# 153713.76613792923
# 153470.02611491972
# 154934.4598527955
# 119976.32895015595
# 131183.88872705016
# 124860.66857743394
# 151726.097968738
# 137851.14874144236
# 155294.0557485875
# 118418.83924943574
# 156251.69790677822
# 153665.88291276226
# 668646.2943799016
# 152120.5529630449
# 143180.9117789733
# 143376.795435517
# 156510.39078689448
# 39300.61725754526
# 93709.87514059604
# 151968.4037308115
# 55449.3936137734
# 155454.49342202995
# 156361.06169677866
# 72413.25543981434
# 121463.78477102646
# 40752.61880494639
# 76605.09866806332
# 141789.09378677869
# 99336.93077604128
# 156221.06976851207
# 150387.35398400758
# 155756.39997464945
# 109484.60494970923
# 151499.90341121829
# 133772.60303772587
# 156451.53592078562
# 125806.67173250826
# 36644.13020202722
# 293655.6184084936
# 138504.51506261496
# 309408.7458453818
# 287856.2154723125
# 252385.9822862188
# 310423.3624438238
# 262035.34830973763
# 307541.88712320186
# 273987.67831110326
# 308974.5704393367
# 310067.4941744895
# 300352.52432847605
# 308580.45923229895
# 306132.82817188854
# 168827.93498601913
# 295446.088882557
# 271518.83597100805
# 151791.38302802495
# 283066.07562418573
# 18725.917322274636
# 289712.8413718291
# 310088.927278433
# 293597.81474285177
# 294002.9336576124
# 309398.4941685658
# 263228.16071616363
# 283900.46857801307
# 261169.55388070294
# 262199.0109557308
# 305098.21471107955
# 295935.209247815
# 240537.54875392915
# 105323.83544409409
# 227158.69180326568
# 310289.9696642814
# 310222.6342404019
# 308017.55268929683
# 309731.6936518608
# 269740.0032392738
# 222445.44363354528
# 309566.9953612817
# 276754.83704069146
# 306663.08569747274
# 307859.3276744591
# 307159.66024270735
# 300895.4208512842
# 310122.6264889414
# 310384.0287502599
# 265597.9150704154
# 298440.6203927364
# 307949.89850697434
# 277095.65264125704
# 304806.83790678007
# 309469.52131177083
# 307741.985388131
# 307548.4598726555
# 308941.1637563465
# 274184.9216577004
# 285194.8210783913
# 279078.1174784078
# 305787.63468311616
# 291951.83383871504
# 309288.05168739497
# 272835.0275034681
# 310228.157469687
# 307698.51001341594
# 514088.19751536316
# 306174.14776961075
# 297309.9920337742
# 297464.1085566734
# 310430.28069447115
# 191450.67794848137
# 246955.94988764427
# 306023.59496429213
# 210445.20420515147
# 309475.0922772297
# 310315.42455332
# 227350.43285192281
# 275380.1833699123
# 195392.03473026477
# 230997.93574247762
# 296011.8033247006
# 253676.6742929853
# 310205.26286433195
# 304385.8538281466
# 309766.3244332442
# 264005.6214033777
# 305567.6970292738
# 287933.95991721994
# 310385.64238406153
# 279817.8431835741
# 188540.37541586653
# 155094.205754785
# 13431.294626971314
# 168421.14120837435
# 3316.5685950804027
# 19264.085647334563
# 54978.412628058424
# 6059.44585496056
# 44788.36881457675
# 1002.4195708707715
# 33029.183125838244
# 4459.49250511245
# 4577.300183657188
# 7173.3098112796315
# 2699.4743809524552
# 3968.661232524645
# 138133.51382273727
# 12000.726908830029
# 37002.02594665161
# 155379.65300666614
# 24583.185744050275
# 289201.9778253763
# 17125.643391815385
# 5020.273599422146
# 13406.42707275156
# 12885.007432639017
# 3785.3260863227947
# 43831.845245123666
# 22929.618870742775
# 45928.29212096236
# 44624.51487508505
# 2268.0878589464123
# 11117.407434177225
# 66721.88704952826
# 410694.58136209974
# 79926.93241117382
# 5048.556658789697
# 4810.9010402388885
# 2493.32684696613
# 3779.471107509723
# 37197.8831386037
# 84811.25739090772
# 4964.993851896621
# 30170.11560045787
# 3126.5397322421927
# 2423.0623149314642
# 1430.3022032659985
# 6014.973708390484
# 5112.8197419113585
# 5618.529018796699
# 41272.591311656026
# 8923.511305355296
# 1674.6499419231775
# 30156.29767889841
# 4162.308464329638
# 3707.1455293805266
# 3938.1086512551005
# 3042.4340313257403
# 3556.1798907557018
# 32723.424315856617
# 21634.614062237768
# 27834.945462511027
# 1261.3775303139225
# 15035.865506316453
# 3233.2999791169277
# 34437.727447335164
# 4826.381704898272
# 3265.5335249805016
# 818014.3315108513
# 2763.4063714779627
# 9790.69072999121
# 9326.886313009316
# 6142.767011364228
# 115400.50329221989
# 60112.8416725171
# 3209.334400626197
# 98348.23615582612
# 3923.845758868621
# 5076.707370700532
# 81059.17231830944
# 31426.860140290988
# 111906.93777325591
# 76047.8063884806
# 10957.942541227265
# 53365.824234214
# 4852.248555502159
# 3390.777157065889
# 4512.127400142568
# 43422.77444983581
# 3703.846494898725
# 19151.252875004775
# 5648.018642732387
# 26995.822203144766
# 118310.27253190645
# 152637.57039069495
# 306729.0009571436
# 3354.3620887692086
# 158604.91278720557
# 13016.84399860527
# 9134.37872402452
# 45018.52607508414
# 15304.837189903896
# 34958.493440037535
# 11094.64832137767
# 23034.551707335188
# 12376.795411466475
# 13774.680744472642
# 3528.833685814291
# 11943.633590790138
# 9315.85032761515
# 128333.00980202704
# 2502.845792554948
# 27286.751097727956
# 145594.01595336193
# 14567.403327538752
# 279385.00154768775
# 7460.484231590137
# 13774.600581569506
# 3408.5505460019644
# 3197.186452068982
# 12851.702416973216
# 33973.24180960305
# 13104.27587737775
# 35998.463312317115
# 34804.089046148096
# 8408.361738927713
# 1222.4317830492205
# 56829.06744662926
# 400907.02781905676
# 70012.95569054643
# 14753.557094281152
# 14190.426902441086
# 11361.824591275634
# 13398.167004957628
# 27292.768370267804
# 74877.5893087405
# 13034.096452828242
# 20170.243467121578
# 9866.376639202415
# 11230.902162671333
# 10666.502594752896
# 4475.978287048362
# 13817.780423557355
# 14889.508183994762
# 31327.68363667771
# 1553.5266149186734
# 11501.768886803195
# 20240.48220464312
# 8036.928007761983
# 13057.30374384288
# 11068.3976795941
# 10766.205812400865
# 12381.453926481085
# 22814.466061842006
# 11846.792624283433
# 17952.532172995576
# 9291.439724769667
# 4991.067154490569
# 12962.589823054099
# 24458.491886023337
# 14166.469777354969
# 11000.990020113146
# 808345.0853134819
# 9428.14627115489
# 707.0197614115602
# 2490.740239378388
# 15328.867238631918
# 105567.84385257568
# 50261.27021329294
# 9264.172882087918
# 88472.65257756869
# 12933.468938856337
# 14656.048324619542
# 71174.28892819281
# 21672.225778974833
# 102009.60833506563
# 66191.04397766327
# 2644.7179114723567
# 43426.09781222091
# 14039.228724564418
# 7838.237839255089
# 13285.812322611868
# 33455.96496471789
# 8793.616516966002
# 8995.94251650307
# 15060.429182337384
# 17177.99254602459
# 108455.71054444612
# 142758.02195941194
# 296903.6493568845
# 10343.614385544382
# 154104.20333302894
# 6235.135804920639
# 169911.47422526436
# 148320.2865383813
# 112846.41278765997
# 170995.24564172837
# 122517.76162698634
# 168032.4011886624
# 134423.00141221643
# 169462.2948814006
# 170576.92754377687
# 160814.66590313264
# 169066.77539410302
# 166596.2922304605
# 29944.399902134184
# 155922.74241371074
# 132034.60906450532
# 15112.51944411707
# 143506.19585642664
# 122135.51458318588
# 150187.57382334807
# 170596.85789528536
# 154058.94754951418
# 154464.8137942314
# 169892.07245953055
# 123667.18036626017
# 144366.78793555245
# 121601.75597465463
# 122646.93370730944
# 165573.273655368
# 156390.03577254358
# 101001.99896753022
# 244029.98584840237
# 87609.43648374354
# 170840.1906418043
# 170747.4897135725
# 168502.35225556494
# 170238.55185254506
# 130176.86676783401
# 82929.70687355472
# 170059.1271901422
# 137210.2363511897
# 167134.35288414508
# 168346.23714024972
# 167651.89104856527
# 161371.7990819713
# 170630.69720628884
# 170937.11541740358
# 126044.23282274955
# 158896.9090453897
# 168444.92501564938
# 137532.83097482994
# 165276.61962352513
# 169973.05421208855
# 168223.63629933205
# 168021.7988539841
# 169434.8779031829
# 134625.21271651113
# 145666.22076195688
# 139523.3957905836
# 166273.44911591354
# 152410.22013574163
# 169795.11446478125
# 133268.82723518056
# 170751.30468024855
# 168180.61135863393
# 652327.7058917485
# 166650.51122595585
# 157767.8664071418
# 157939.11727472302
# 171003.4431052753
# 52024.74908922657
# 107531.18891382859
# 166498.74407929694
# 71718.94195628338
# 169969.32386129608
# 170859.78975832163
# 88185.24174091418
# 135860.61129059715
# 56013.36470097365
# 91449.3017869963
# 156469.5850423654
# 114105.96769462322
# 170722.26246951308
# 164871.6688721138
# 170263.74143181657
# 124450.90247014308
# 166039.3973625659
# 148379.9179492895
# 170946.63881302782
# 140284.46088612295
# 49119.479984066726
# 18090.508526913887
# 139583.5535330102
# 167216.70494529043
# 157357.52997661452
# 49746.49630485809
# 106006.22688926093
# 65743.1153260071
# 44112.10067317029
# 8548.726316803071
# 67048.2468916085
# 18976.993753481
# 63817.45124849255
# 30008.5083438151
# 65257.07696065975
# 66432.22454075173
# 56525.75157818215
# 64840.41249820979
# 62285.35112039248
# 75909.34472468907
# 51749.8324509028
# 27861.696290455744
# 93232.12849225926
# 39008.36521607317
# 226620.60928446244
# 46019.914557915
# 66449.02456079173
# 49795.11243300911
# 50185.49611835732
# 65695.72669965021
# 19244.29684686556
# 40192.89500542922
# 17118.504962896848
# 18524.181790837592
# 61312.57719609867
# 52058.96964808927
# 4387.692295344952
# 348245.8282341467
# 16992.34657166514
# 66821.07020853278
# 66650.20631381318
# 64278.862123266525
# 66083.88021446399
# 25798.329961496398
# 21860.057199228835
# 65861.93856258145
# 33032.140008163864
# 62863.6357373555
# 64134.16117354662
# 63458.18386130469
# 57134.49803487919
# 66483.45647771236
# 66928.48583945751
# 21923.81273086999
# 54575.984615708025
# 64253.74564129156
# 33045.90763421686
# 61010.23982323324
# 65811.940746308
# 63998.97953065109
# 63755.10897989296
# 65245.87666638575
# 30275.864194343532
# 41509.36809675695
# 35165.96452493187
# 62048.944697580635
# 48130.07032312637
# 65646.35494357852
# 28765.97013869198
# 66648.15669841944
# 63954.04922918937
# 756285.2523592421
# 62405.28988545392
# 53459.86002933343
# 53702.15749044482
# 67059.77570626987
# 53077.71274395727
# 9354.081072884634
# 62248.56032217265
# 36144.50940517184
# 65774.03184237429
# 66822.7815669568
# 19384.00502556711
# 31900.253587376803
# 48983.8253841164
# 13294.489663127853
# 52121.45492762029
# 9631.53630180199
# 66600.26371856264
# 60683.35627623017
# 66082.65165295513
# 19965.42234235213
# 61776.40440599842
# 44041.959856425834
# 66965.80589404343
# 36151.11077899791
# 55944.317939716384
# 89733.99535526428
# 244082.18252106375
# 62984.517385110266
# 53030.92319175209
# 104513.07270527305
# 12535.700082689846
# 143149.09204118335
# 28689.57278802036
# 7498.004623055425
# 29227.714987290707
# 30398.49889229946
# 19911.793521012543
# 26737.544735300482
# 7418.9434134276735
# 28114.831117642116
# 29400.364385787187
# 19333.55572889017
# 27698.68108585856
# 25037.015081416535
# 112931.15946415128
# 14833.560183871388
# 12119.428476128347
# 130225.73543079472
# 2412.225134824131
# 263867.6592706573
# 9488.53083543232
# 29402.836599587423
# 12759.098389178169
# 13150.068908068324
# 28582.760065205508
# 18299.124263757858
# 4735.73245082434
# 20272.07603424947
# 19383.952490622432
# 24157.374448256112
# 14872.161170115098
# 41079.23299846115
# 385415.2276041742
# 54308.73429597564
# 30042.97693321015
# 29706.03695977227
# 27136.647166408828
# 29046.99604414891
# 11737.165978806835
# 59139.91706962778
# 28733.12165675496
# 5619.946264455721
# 25657.091229464157
# 27005.9719257599
# 26380.7387479438
# 20059.330030827507
# 29438.35963321506
# 30155.26922734273
# 15987.251498573245
# 17357.92785003863
# 27185.33480316876
# 4597.313221267876
# 23813.393315367415
# 28752.08871889295
# 26834.566939972072
# 26552.08171828485
# 28135.145180185744
# 7429.331477738698
# 5723.663522967822
# 3144.438894598918
# 24958.620932416416
# 11101.15980017902
# 28620.084129899285
# 8667.605462069941
# 29693.135348914675
# 26792.276036652787
# 793170.6368308065
# 25234.17808022123
# 16284.904828437175
# 16726.215878850755
# 30413.720200909895
# 90120.27654799526
# 35264.751519204976
# 25066.88674955621
# 72668.76577452323
# 28660.703389001897
# 30002.42891285263
# 55372.594690257916
# 7690.714309017362
# 86290.7921764259
# 50512.4648514502
# 15018.52628203317
# 27725.96717662515
# 29608.470478030158
# 23605.61687773725
# 28984.319095450308
# 17647.715801564453
# 24580.10699681609
# 6963.8759258197615
# 30251.703157112148
# 4320.990800999141
# 93001.84133063561
# 127030.41720460157
# 281352.55752449017
# 25910.010041338857
# 15819.164238703144
# 141785.32224490115
# 37325.673085008646
# 313565.9906857365
# 158252.6822484251
# 329182.89096509566
# 307695.0096229338
# 272667.32166973257
# 330178.41097954306
# 281839.47309350246
# 327348.32443700463
# 293998.41299363587
# 328749.4513187953
# 329834.9693697631
# 320193.4281064262
# 328375.3078031802
# 325979.9369362849
# 188464.86055879373
# 315234.1503486175
# 291913.399537061
# 171196.042837344
# 303183.3069678925
# 38929.2096100993
# 309528.9247003482
# 329855.32320517115
# 313443.04693804326
# 313865.364114477
# 329176.66303674015
# 283336.72897262976
# 303741.083313246
# 281287.6291816677
# 282160.2135883053
# 324919.30999099463
# 315822.2345382697
# 260831.704904933
# 89052.68036346608
# 247445.23885959567
# 330049.6084921775
# 329984.878436674
# 327806.49248727993
# 329502.1645994741
# 289749.8533402876
# 242820.69218863128
# 329344.67130865547
# 296621.48879005195
# 326477.4793649746
# 327641.29180936486
# 326940.9837251089
# 320715.25693798217
# 329889.82640290394
# 330142.4833172031
# 285503.2469328656
# 318308.64158411964
# 327735.09457761305
# 297190.9151583782
# 324621.0760714972
# 329234.6420388111
# 327525.8329964969
# 327359.8777542177
# 328710.5990952912
# 294158.8397712947
# 305023.9666600723
# 299050.3707471377
# 325595.7361446879
# 311813.28115593985
# 329052.7639496476
# 292946.61023856956
# 329991.7103431092
# 327483.53821534227
# 492649.99987795006
# 325972.88477476925
# 317174.2057377498
# 317305.39205538825
# 330185.5912406999
# 211266.77712262768
# 266601.9383540953
# 325825.6378861603
# 231476.34091047055
# 329253.5553711378
# 330075.1979323273
# 248138.7280932726
# 295185.4601887269
# 215946.7174380661
# 251225.66659503264
# 315940.97745389084
# 273795.8330214007
# 329970.7903350155
# 324155.5228824464
# 329539.06495113974
# 284216.0194318701
# 325378.5343710379
# 307842.22712114314
# 330141.91842352314
# 299660.07700619387
# 208380.96962125314
# 176155.37324301866
# 25922.403445308424
# 326555.68975058984
# 316779.25431779056
# 159986.60311237437
# 264253.25642513105
# 301380.01399500726
# Running query with input_anime_names: ['Mahou Shoujo Lyrical Nanoha StrikerS']
# <neo4j._sync.work.result.Result object at 0x7fbf0986e190>
# Processed user input: Mahou Shoujo Lyrical Nanoha StrikerS

# %%
# # Insert your existing code here, but remove the following lines:
# # graph.delete_all()
# # and
# # print("Recommendations:")



# def get_recommendations():
#     try:
#         driver = GraphDatabase.driver("bolt://localhost:7687", auth=("neo4j", "Ywt200151753."))
#         graph = driver.session()
        
#         for i in range(len(df)):
#             for j in range(0, i):
#                 anime1 = anime_nodes[i]
#                 anime2 = anime_nodes[j]
#                 distance = float(similarity_matrix[i][j])

#                 # create relationship between the songs that meet threshold
#                 if distance < 3000:
#                 # create a similarity relationship between the songs
#                     similarity_rel = Relationship(anime1, "SIMILAR_TO", anime2, distance=distance)
#                     print(similarity_rel)
#                 # create the relationship in the database
#                     graph.create(similarity_rel)
        
        

#         # Insert the code for the Cypher query here (cypher_query variable)

#         results = graph.run(cypher_query)

#         # Clear the existing recommendations
#         recommendation_text.delete(1.0, tk.END)

#         # Insert the recommendations into the text widget
#         for record in results:
#             recommendation_text.insert(tk.END, f"Anime: {record['a2']['title']}, Studio: {record['a2']['studio']}, Distance: {record['min_distance']}\n")

#         graph.close()
#     except ServiceUnavailable as e:
#         print(f"Neo4j service unavailable: {e}")


# # Create the main window
# root = tk.Tk()
# root.title("Anime Recommendation System")

# # Create and pack the widgets
# frame = ttk.Frame(root, padding="10")
# frame.grid(row=0, column=0, sticky=(tk.W, tk.E, tk.N, tk.S))

# get_recommendations_button = ttk.Button(frame, text="Get Recommendations", command=get_recommendations)
# get_recommendations_button.grid(row=0, column=0, pady=(0, 10))

# recommendation_text = tk.Text(frame, wrap=tk.WORD, width=80, height=20)
# recommendation_text.grid(row=1, column=0)

# scrollbar = ttk.Scrollbar(frame, orient=tk.VERTICAL, command=recommendation_text.yview)
# scrollbar.grid(row=1, column=1, sticky=(tk.N, tk.S))
# recommendation_text["yscrollcommand"] = scrollbar.set

# root.mainloop()

# %%
python anime_recommendation_gui.py
# Out:
#   File "<ipython-input-18-d14def5fd8bd>", line 1
#     python anime_recommendation_gui.py
#            ^
# SyntaxError: invalid syntax

# %%
df.head()
